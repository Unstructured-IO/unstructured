# %%
# !pip install weaviate-client

# %%
# load creds from .env file
import os
with open('.env', 'r') as env_file:
    for line in env_file:
        key, value = line.strip().split('=')
        os.environ[key] = value

# %%
import os
import uuid

import weaviate
from weaviate.embedded import EmbeddedOptions
from weaviate.util import get_valid_uuid

from unstructured.chunking.title import chunk_by_title
from unstructured.documents.elements import DataSourceMetadata
from unstructured.partition.json import partition_json

COHERE_KEY = os.environ.get("COHERE_API_KEY")
OPENAI_KEY = os.environ.get("OPENAI_API_KEY")

# %%
# fetch our partitioned documents

def get_result_files(folder_path):
    file_list = []
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            if file.endswith('.json'):
                file_path = os.path.join(root, file)
                file_list.append(file_path)
    return file_list

files = get_result_files('results/')
files
# Out:
# ['results/1ZBXs78r2SSgYUZI_ZOwZm_yt7A4n6NL8-FOMC20170201tealbookb20170126.pdf.json',
#  'results/1ppcP-AOkTB5ln7CqnwQy9l_Kvtftn4L0-NAE-report-on-quantum-computing.pdf.json',
#  'results/1ps9S0TaMC02NahJAfp3NyZo6NVmf7rpM-COVID-19 Accelerates Quantum Computing Adoption, Driving Robust Growth in North America, Europe, and Asia-Pacific.pdf.json',
#  "results/1TwH2WPshvwueAHlDiMfe9STLtFgOx-uB-NASA's SpaceX Crew-7 Launches to International Space Station.pdf.json",
#  'results/1AahuJfN_mmiqqP5E9byMj3cQBZJCanqmZW-YDSaCPC4-Quantum Photonics Market.docx.json',
#  'results/180MZG3uAnSsSUbWtTqm2Gmv4GYpe2dnY-honeywell-quantum-encryption.docx.json',
#  'results/EmailMessage/02sHn00001EwshAIAR.json',
#  'results/EmailMessage/02sHn00001EwshBIAR.json',
#  'results/EmailMessage/02sHn00001EwshFIAR.json',
#  'results/EmailMessage/02sHn00001EwshtIAB.json',
#  'results/Lead/00QHn000021npFsMAI.json',
#  'results/Lead/00QHn000021npG6MAI.json',
#  'results/Lead/00QHn000021npFzMAI.json',
#  'results/Lead/00QHn000021npFoMAI.json',
#  'results/Lead/00QHn000021npFnMAI.json',
#  'results/Lead/00QHn000021npFrMAI.json',
#  'results/Lead/00QHn000021npG7MAI.json',
#  'results/Lead/00QHn000021npFyMAI.json',
#  'results/Lead/00QHn000021npFpMAI.json',
#  'results/Lead/00QHn000021npG5MAI.json',
#  'results/Lead/00QHn000021npFqMAI.json',
#  'results/Lead/00QHn000021npG4MAI.json',
#  'results/Lead/00QHn000021npFxMAI.json',
#  'results/Lead/00QHn000021npG8MAI.json',
#  'results/Lead/00QHn000021npG1MAI.json',
#  'results/Lead/00QHn000021npFtMAI.json',
#  'results/Lead/00QHn000021npG0MAI.json',
#  'results/Lead/00QHn000021npFuMAI.json',
#  'results/Lead/00QHn000021npG2MAI.json',
#  'results/Lead/00QHn000021npFwMAI.json',
#  'results/Lead/00QHn000021npG3MAI.json',
#  'results/Lead/00QHn000021npFvMAI.json',
#  'results/Campaign/701Hn000001dWeWIAU.json',
#  'results/Campaign/701Hn000001dWeZIAU.json',
#  'results/Campaign/701Hn000001dWeXIAU.json',
#  'results/Campaign/701Hn000001dWeYIAU.json',
#  'results/Case/500Hn00001bslfuIAA.json',
#  'results/Case/500Hn00001bslg0IAA.json',
#  'results/Case/500Hn00001bslg9IAA.json',
#  'results/Case/500Hn00001bslg8IAA.json',
#  'results/Case/500Hn00001bslftIAA.json',
#  'results/Case/500Hn00001bslg1IAA.json',
#  'results/Case/500Hn00001bslfvIAA.json',
#  'results/Case/500Hn00001bslg3IAA.json',
#  'results/Case/500Hn00001bslfwIAA.json',
#  'results/Case/500Hn00001bslg2IAA.json',
#  'results/Case/500Hn00001bslfnIAA.json',
#  'results/Case/500Hn00001bslg7IAA.json',
#  'results/Case/500Hn00001bslgAIAQ.json',
#  'results/Case/500Hn00001bslfrIAA.json',
#  'results/Case/500Hn00001bslg6IAA.json',
#  'results/Case/500Hn00001bslfsIAA.json',
#  'results/Case/500Hn00001bslfzIAA.json',
#  'results/Case/500Hn00001bslfoIAA.json',
#  'results/Case/500Hn00001bslg4IAA.json',
#  'results/Case/500Hn00001bslfqIAA.json',
#  'results/Case/500Hn00001bslgBIAQ.json',
#  'results/Case/500Hn00001bslfmIAA.json',
#  'results/Case/500Hn00001bslfxIAA.json',
#  'results/Case/500Hn00001bslfyIAA.json',
#  'results/Case/500Hn00001bslg5IAA.json',
#  'results/Case/500Hn00001bslfpIAA.json',
#  'results/Account/001Hn00001wCnWKIA0.json',
#  'results/Account/001Hn00001wCnWJIA0.json',
#  'results/Account/001Hn00001wCnWTIA0.json',
#  'results/Account/001Hn00001wCnWIIA0.json',
#  'results/Account/001Hn00001wCnWLIA0.json',
#  'results/Account/001Hn00001wCnWPIA0.json',
#  'results/Account/001Hn00001wCnWQIA0.json',
#  'results/Account/001Hn00001wCnWMIA0.json',
#  'results/Account/001Hn00001wCnWSIA0.json',
#  'results/Account/001Hn00001wCnWOIA0.json',
#  'results/Account/001Hn00001tJVo9IAG.json',
#  'results/Account/001Hn00001wCnWNIA0.json',
#  'results/Account/001Hn00001wCnWRIA0.json']

# %%
# Set up a weaviate client with document schema

def create_local_weaviate_client():
    return weaviate.Client(
        embedded_options=EmbeddedOptions(
            additional_env_vars={
                "ENABLE_MODULES": "text2vec-openai,reranker-cohere"
            },
        ),
        additional_headers={
            "X-OpenAI-Api-Key": OPENAI_KEY,
            "X-Cohere-API-Key": COHERE_KEY
        },
    )

def get_schema():
    vectorizer = "text2vec-openai"
    return {
        "classes": [
            {
                "class": "Doc",
                "description": "A generic document class",
                "vectorizer": vectorizer,
                "moduleConfig": {"reranker-cohere": {"model": "rerank-multilingual-v2.0"}},
                "properties": [
                    {
                        "name": "last_modified",
                        "dataType": ["text"],
                        "description": "Last modified date for the document",
                        "moduleConfig": {
                            vectorizer: {
                                "skip": True,  # not including the this property for vectorization
                            },
                        },
                    },
                    {
                        "name": "text",
                        "dataType": ["text"],
                        "description": "Text content for the document",
                    },
                ],
            },
        ],
    }

def upload_schema(my_schema, weaviate):
    weaviate.schema.delete_all()
    weaviate.schema.create(my_schema)

client = create_local_weaviate_client()
my_schema = get_schema()
upload_schema(my_schema, weaviate=client)
# Out:
# embedded weaviate is already listening on port 6666
# Embedded weaviate wasn't listening on port 6666, so starting embedded weaviate again
# Started /Users/ryannikolaidis/.cache/weaviate-embedded: process ID 52042
# {"action":"restapi_management","level":"info","msg":"Shutting down... ","time":"2023-09-08T00:15:24-07:00"}
# {"action":"restapi_management","level":"info","msg":"Stopped serving weaviate at http://127.0.0.1:6666","time":"2023-09-08T00:15:24-07:00"}
# {"action":"startup","default_vectorizer_module":"none","level":"info","msg":"the default vectorizer modules is set to \"none\", as a result all new schema classes without an explicit vectorizer setting, will use this vectorizer","time":"2023-09-08T00:15:24-07:00"}
# {"action":"startup","auto_schema_enabled":true,"level":"info","msg":"auto schema enabled setting is set to \"true\"","time":"2023-09-08T00:15:24-07:00"}
# {"level":"warning","msg":"Multiple vector spaces are present, GraphQL Explore and REST API list objects endpoint module include params has been disabled as a result.","time":"2023-09-08T00:15:24-07:00"}
# {"action":"grpc_startup","level":"info","msg":"grpc server listening at [::]:50051","time":"2023-09-08T00:15:24-07:00"}
# {"action":"hnsw_vector_cache_prefill","count":5000,"index_id":"doc_2AMzpgnJ9bMz","level":"info","limit":1000000000000,"msg":"prefilled vector cache","time":"2023-09-08T00:15:24-07:00","took":10879708}
# {"action":"restapi_management","level":"info","msg":"Serving weaviate at http://127.0.0.1:6666","time":"2023-09-08T00:15:24-07:00"}
# {"action":"hnsw_vector_cache_prefill","count":1000,"index_id":"doc_SaNl050mFmXD","level":"info","limit":1000000000000,"msg":"prefilled vector cache","time":"2023-09-08T00:15:24-07:00","took":37000}

# %%
def get_chunks(elements, chunk_under_n_chars=500, chunk_new_after_n_chars=1500):
    for element in elements:
        if not type(element.metadata.data_source) is DataSourceMetadata:
            # note: data_source attribute is assigned as a dict and this breaks chunking
            delattr(element.metadata, "data_source")

        if hasattr(element.metadata, "coordinates"):
            # note: coordinates attribute maps each element to an individual chunk,
            # this breaks chunking logically (outputs lots of small chunks)
            delattr(element.metadata, "coordinates")

    chunks = chunk_by_title(
        elements,
        combine_under_n_chars=chunk_under_n_chars,
        new_after_n_chars=chunk_new_after_n_chars
    )

    for i in range(len(chunks)):
        chunks[i] = {"last_modified": chunks[i].metadata.last_modified, "text": chunks[i].text}

    return chunks


def add_data_to_weaviate(files, weaviate, chunk_under_n_chars=500, chunk_new_after_n_chars=1500):
    for filename in files:
        try:
            elements = partition_json(filename=filename)
            chunks = get_chunks(elements, chunk_under_n_chars, chunk_new_after_n_chars)
            print(f"\n\n{str(filename)} is succesfully processed.")
        except IndexError as e:
            print(e)
            continue

        for i, chunk in enumerate(chunks):
            print(f"Adding chunk {i} of {len(chunks)} to weaviate")
            weaviate.batch.add_data_object(
                data_object=chunk,
                class_name="doc",
                uuid=get_valid_uuid(uuid.uuid4()),
            )
        
    weaviate.batch.flush()

add_data_to_weaviate(
    files=files,
    weaviate=client,
    chunk_under_n_chars=75,
    chunk_new_after_n_chars=200
)
# Out:
# results/1ZBXs78r2SSgYUZI_ZOwZm_yt7A4n6NL8-FOMC20170201tealbookb20170126.pdf.json is succesfully processed.
# Adding chunk 0 of 295 to weaviate
# Adding chunk 1 of 295 to weaviate
# Adding chunk 2 of 295 to weaviate
# Adding chunk 3 of 295 to weaviate
# Adding chunk 4 of 295 to weaviate
# Adding chunk 5 of 295 to weaviate
# Adding chunk 6 of 295 to weaviate
# Adding chunk 7 of 295 to weaviate
# Adding chunk 8 of 295 to weaviate
# Adding chunk 9 of 295 to weaviate
# Adding chunk 10 of 295 to weaviate
# Adding chunk 11 of 295 to weaviate
# Adding chunk 12 of 295 to weaviate
# Adding chunk 13 of 295 to weaviate
# Adding chunk 14 of 295 to weaviate
# Adding chunk 15 of 295 to weaviate
# Adding chunk 16 of 295 to weaviate
# Adding chunk 17 of 295 to weaviate
# Adding chunk 18 of 295 to weaviate
# Adding chunk 19 of 295 to weaviate
# Adding chunk 20 of 295 to weaviate
# Adding chunk 21 of 295 to weaviate
# Adding chunk 22 of 295 to weaviate
# Adding chunk 23 of 295 to weaviate
# Adding chunk 24 of 295 to weaviate
# Adding chunk 25 of 295 to weaviate
# Adding chunk 26 of 295 to weaviate
# Adding chunk 27 of 295 to weaviate
# Adding chunk 28 of 295 to weaviate
# Adding chunk 29 of 295 to weaviate
# Adding chunk 30 of 295 to weaviate
# Adding chunk 31 of 295 to weaviate
# Adding chunk 32 of 295 to weaviate
# Adding chunk 33 of 295 to weaviate
# Adding chunk 34 of 295 to weaviate
# Adding chunk 35 of 295 to weaviate
# Adding chunk 36 of 295 to weaviate
# Adding chunk 37 of 295 to weaviate
# Adding chunk 38 of 295 to weaviate
# Adding chunk 39 of 295 to weaviate
# Adding chunk 40 of 295 to weaviate
# Adding chunk 41 of 295 to weaviate
# Adding chunk 42 of 295 to weaviate
# Adding chunk 43 of 295 to weaviate
# Adding chunk 44 of 295 to weaviate
# Adding chunk 45 of 295 to weaviate
# Adding chunk 46 of 295 to weaviate
# Adding chunk 47 of 295 to weaviate
# Adding chunk 48 of 295 to weaviate
# Adding chunk 49 of 295 to weaviate
# Adding chunk 50 of 295 to weaviate
# Adding chunk 51 of 295 to weaviate
# Adding chunk 52 of 295 to weaviate
# Adding chunk 53 of 295 to weaviate
# Adding chunk 54 of 295 to weaviate
# Adding chunk 55 of 295 to weaviate
# Adding chunk 56 of 295 to weaviate
# Adding chunk 57 of 295 to weaviate
# Adding chunk 58 of 295 to weaviate
# Adding chunk 59 of 295 to weaviate
# Adding chunk 60 of 295 to weaviate
# Adding chunk 61 of 295 to weaviate
# Adding chunk 62 of 295 to weaviate
# Adding chunk 63 of 295 to weaviate
# Adding chunk 64 of 295 to weaviate
# Adding chunk 65 of 295 to weaviate
# Adding chunk 66 of 295 to weaviate
# Adding chunk 67 of 295 to weaviate
# Adding chunk 68 of 295 to weaviate
# Adding chunk 69 of 295 to weaviate
# Adding chunk 70 of 295 to weaviate
# Adding chunk 71 of 295 to weaviate
# Adding chunk 72 of 295 to weaviate
# Adding chunk 73 of 295 to weaviate
# Adding chunk 74 of 295 to weaviate
# Adding chunk 75 of 295 to weaviate
# Adding chunk 76 of 295 to weaviate
# Adding chunk 77 of 295 to weaviate
# Adding chunk 78 of 295 to weaviate
# Adding chunk 79 of 295 to weaviate
# Adding chunk 80 of 295 to weaviate
# Adding chunk 81 of 295 to weaviate
# Adding chunk 82 of 295 to weaviate
# Adding chunk 83 of 295 to weaviate
# Adding chunk 84 of 295 to weaviate
# Adding chunk 85 of 295 to weaviate
# Adding chunk 86 of 295 to weaviate
# Adding chunk 87 of 295 to weaviate
# Adding chunk 88 of 295 to weaviate
# Adding chunk 89 of 295 to weaviate
# Adding chunk 90 of 295 to weaviate
# Adding chunk 91 of 295 to weaviate
# Adding chunk 92 of 295 to weaviate
# Adding chunk 93 of 295 to weaviate
# Adding chunk 94 of 295 to weaviate
# Adding chunk 95 of 295 to weaviate
# Adding chunk 96 of 295 to weaviate
# Adding chunk 97 of 295 to weaviate
# Adding chunk 98 of 295 to weaviate
# Adding chunk 99 of 295 to weaviate
# Adding chunk 100 of 295 to weaviate
# Adding chunk 101 of 295 to weaviate
# Adding chunk 102 of 295 to weaviate
# Adding chunk 103 of 295 to weaviate
# Adding chunk 104 of 295 to weaviate
# Adding chunk 105 of 295 to weaviate
# Adding chunk 106 of 295 to weaviate
# Adding chunk 107 of 295 to weaviate
# Adding chunk 108 of 295 to weaviate
# Adding chunk 109 of 295 to weaviate
# Adding chunk 110 of 295 to weaviate
# Adding chunk 111 of 295 to weaviate
# Adding chunk 112 of 295 to weaviate
# Adding chunk 113 of 295 to weaviate
# Adding chunk 114 of 295 to weaviate
# Adding chunk 115 of 295 to weaviate
# Adding chunk 116 of 295 to weaviate
# Adding chunk 117 of 295 to weaviate
# Adding chunk 118 of 295 to weaviate
# Adding chunk 119 of 295 to weaviate
# Adding chunk 120 of 295 to weaviate
# Adding chunk 121 of 295 to weaviate
# Adding chunk 122 of 295 to weaviate
# Adding chunk 123 of 295 to weaviate
# Adding chunk 124 of 295 to weaviate
# Adding chunk 125 of 295 to weaviate
# Adding chunk 126 of 295 to weaviate
# Adding chunk 127 of 295 to weaviate
# Adding chunk 128 of 295 to weaviate
# Adding chunk 129 of 295 to weaviate
# Adding chunk 130 of 295 to weaviate
# Adding chunk 131 of 295 to weaviate
# Adding chunk 132 of 295 to weaviate
# Adding chunk 133 of 295 to weaviate
# Adding chunk 134 of 295 to weaviate
# Adding chunk 135 of 295 to weaviate
# Adding chunk 136 of 295 to weaviate
# Adding chunk 137 of 295 to weaviate
# Adding chunk 138 of 295 to weaviate
# Adding chunk 139 of 295 to weaviate
# Adding chunk 140 of 295 to weaviate
# Adding chunk 141 of 295 to weaviate
# Adding chunk 142 of 295 to weaviate
# Adding chunk 143 of 295 to weaviate
# Adding chunk 144 of 295 to weaviate
# Adding chunk 145 of 295 to weaviate
# Adding chunk 146 of 295 to weaviate
# Adding chunk 147 of 295 to weaviate
# Adding chunk 148 of 295 to weaviate
# Adding chunk 149 of 295 to weaviate
# Adding chunk 150 of 295 to weaviate
# Adding chunk 151 of 295 to weaviate
# Adding chunk 152 of 295 to weaviate
# Adding chunk 153 of 295 to weaviate
# Adding chunk 154 of 295 to weaviate
# Adding chunk 155 of 295 to weaviate
# Adding chunk 156 of 295 to weaviate
# Adding chunk 157 of 295 to weaviate
# Adding chunk 158 of 295 to weaviate
# Adding chunk 159 of 295 to weaviate
# Adding chunk 160 of 295 to weaviate
# Adding chunk 161 of 295 to weaviate
# Adding chunk 162 of 295 to weaviate
# Adding chunk 163 of 295 to weaviate
# Adding chunk 164 of 295 to weaviate
# Adding chunk 165 of 295 to weaviate
# Adding chunk 166 of 295 to weaviate
# Adding chunk 167 of 295 to weaviate
# Adding chunk 168 of 295 to weaviate
# Adding chunk 169 of 295 to weaviate
# Adding chunk 170 of 295 to weaviate
# Adding chunk 171 of 295 to weaviate
# Adding chunk 172 of 295 to weaviate
# Adding chunk 173 of 295 to weaviate
# Adding chunk 174 of 295 to weaviate
# Adding chunk 175 of 295 to weaviate
# Adding chunk 176 of 295 to weaviate
# Adding chunk 177 of 295 to weaviate
# Adding chunk 178 of 295 to weaviate
# Adding chunk 179 of 295 to weaviate
# Adding chunk 180 of 295 to weaviate
# Adding chunk 181 of 295 to weaviate
# Adding chunk 182 of 295 to weaviate
# Adding chunk 183 of 295 to weaviate
# Adding chunk 184 of 295 to weaviate
# Adding chunk 185 of 295 to weaviate
# Adding chunk 186 of 295 to weaviate
# Adding chunk 187 of 295 to weaviate
# Adding chunk 188 of 295 to weaviate
# Adding chunk 189 of 295 to weaviate
# Adding chunk 190 of 295 to weaviate
# Adding chunk 191 of 295 to weaviate
# Adding chunk 192 of 295 to weaviate
# Adding chunk 193 of 295 to weaviate
# Adding chunk 194 of 295 to weaviate
# Adding chunk 195 of 295 to weaviate
# Adding chunk 196 of 295 to weaviate
# Adding chunk 197 of 295 to weaviate
# Adding chunk 198 of 295 to weaviate
# Adding chunk 199 of 295 to weaviate
# Adding chunk 200 of 295 to weaviate
# Adding chunk 201 of 295 to weaviate
# Adding chunk 202 of 295 to weaviate
# Adding chunk 203 of 295 to weaviate
# Adding chunk 204 of 295 to weaviate
# Adding chunk 205 of 295 to weaviate
# Adding chunk 206 of 295 to weaviate
# Adding chunk 207 of 295 to weaviate
# Adding chunk 208 of 295 to weaviate
# Adding chunk 209 of 295 to weaviate
# Adding chunk 210 of 295 to weaviate
# Adding chunk 211 of 295 to weaviate
# Adding chunk 212 of 295 to weaviate
# Adding chunk 213 of 295 to weaviate
# Adding chunk 214 of 295 to weaviate
# Adding chunk 215 of 295 to weaviate
# Adding chunk 216 of 295 to weaviate
# Adding chunk 217 of 295 to weaviate
# Adding chunk 218 of 295 to weaviate
# Adding chunk 219 of 295 to weaviate
# Adding chunk 220 of 295 to weaviate
# Adding chunk 221 of 295 to weaviate
# Adding chunk 222 of 295 to weaviate
# Adding chunk 223 of 295 to weaviate
# Adding chunk 224 of 295 to weaviate
# Adding chunk 225 of 295 to weaviate
# Adding chunk 226 of 295 to weaviate
# Adding chunk 227 of 295 to weaviate
# Adding chunk 228 of 295 to weaviate
# Adding chunk 229 of 295 to weaviate
# Adding chunk 230 of 295 to weaviate
# Adding chunk 231 of 295 to weaviate
# Adding chunk 232 of 295 to weaviate
# Adding chunk 233 of 295 to weaviate
# Adding chunk 234 of 295 to weaviate
# Adding chunk 235 of 295 to weaviate
# Adding chunk 236 of 295 to weaviate
# Adding chunk 237 of 295 to weaviate
# Adding chunk 238 of 295 to weaviate
# Adding chunk 239 of 295 to weaviate
# Adding chunk 240 of 295 to weaviate
# Adding chunk 241 of 295 to weaviate
# Adding chunk 242 of 295 to weaviate
# Adding chunk 243 of 295 to weaviate
# Adding chunk 244 of 295 to weaviate
# Adding chunk 245 of 295 to weaviate
# Adding chunk 246 of 295 to weaviate
# Adding chunk 247 of 295 to weaviate
# Adding chunk 248 of 295 to weaviate
# Adding chunk 249 of 295 to weaviate
# Adding chunk 250 of 295 to weaviate
# Adding chunk 251 of 295 to weaviate
# Adding chunk 252 of 295 to weaviate
# Adding chunk 253 of 295 to weaviate
# Adding chunk 254 of 295 to weaviate
# Adding chunk 255 of 295 to weaviate
# Adding chunk 256 of 295 to weaviate
# Adding chunk 257 of 295 to weaviate
# Adding chunk 258 of 295 to weaviate
# Adding chunk 259 of 295 to weaviate
# Adding chunk 260 of 295 to weaviate
# Adding chunk 261 of 295 to weaviate
# Adding chunk 262 of 295 to weaviate
# Adding chunk 263 of 295 to weaviate
# Adding chunk 264 of 295 to weaviate
# Adding chunk 265 of 295 to weaviate
# Adding chunk 266 of 295 to weaviate
# Adding chunk 267 of 295 to weaviate
# Adding chunk 268 of 295 to weaviate
# Adding chunk 269 of 295 to weaviate
# Adding chunk 270 of 295 to weaviate
# Adding chunk 271 of 295 to weaviate
# Adding chunk 272 of 295 to weaviate
# Adding chunk 273 of 295 to weaviate
# Adding chunk 274 of 295 to weaviate
# Adding chunk 275 of 295 to weaviate
# Adding chunk 276 of 295 to weaviate
# Adding chunk 277 of 295 to weaviate
# Adding chunk 278 of 295 to weaviate
# Adding chunk 279 of 295 to weaviate
# Adding chunk 280 of 295 to weaviate
# Adding chunk 281 of 295 to weaviate
# Adding chunk 282 of 295 to weaviate
# Adding chunk 283 of 295 to weaviate
# Adding chunk 284 of 295 to weaviate
# Adding chunk 285 of 295 to weaviate
# Adding chunk 286 of 295 to weaviate
# Adding chunk 287 of 295 to weaviate
# Adding chunk 288 of 295 to weaviate
# Adding chunk 289 of 295 to weaviate
# Adding chunk 290 of 295 to weaviate
# Adding chunk 291 of 295 to weaviate
# Adding chunk 292 of 295 to weaviate
# Adding chunk 293 of 295 to weaviate
# Adding chunk 294 of 295 to weaviate
#
#
# results/1ppcP-AOkTB5ln7CqnwQy9l_Kvtftn4L0-NAE-report-on-quantum-computing.pdf.json is succesfully processed.
# Adding chunk 0 of 58 to weaviate
# Adding chunk 1 of 58 to weaviate
# Adding chunk 2 of 58 to weaviate
# Adding chunk 3 of 58 to weaviate
# Adding chunk 4 of 58 to weaviate
# Adding chunk 5 of 58 to weaviate
# Adding chunk 6 of 58 to weaviate
# Adding chunk 7 of 58 to weaviate
# Adding chunk 8 of 58 to weaviate
# Adding chunk 9 of 58 to weaviate
# Adding chunk 10 of 58 to weaviate
# Adding chunk 11 of 58 to weaviate
# Adding chunk 12 of 58 to weaviate
# Adding chunk 13 of 58 to weaviate
# Adding chunk 14 of 58 to weaviate
# Adding chunk 15 of 58 to weaviate
# Adding chunk 16 of 58 to weaviate
# Adding chunk 17 of 58 to weaviate
# Adding chunk 18 of 58 to weaviate
# Adding chunk 19 of 58 to weaviate
# Adding chunk 20 of 58 to weaviate
# Adding chunk 21 of 58 to weaviate
# Adding chunk 22 of 58 to weaviate
# Adding chunk 23 of 58 to weaviate
# Adding chunk 24 of 58 to weaviate
# Adding chunk 25 of 58 to weaviate
# Adding chunk 26 of 58 to weaviate
# Adding chunk 27 of 58 to weaviate
# Adding chunk 28 of 58 to weaviate
# Adding chunk 29 of 58 to weaviate
# Adding chunk 30 of 58 to weaviate
# Adding chunk 31 of 58 to weaviate
# Adding chunk 32 of 58 to weaviate
# Adding chunk 33 of 58 to weaviate
# Adding chunk 34 of 58 to weaviate
# Adding chunk 35 of 58 to weaviate
# Adding chunk 36 of 58 to weaviate
# Adding chunk 37 of 58 to weaviate
# Adding chunk 38 of 58 to weaviate
# Adding chunk 39 of 58 to weaviate
# Adding chunk 40 of 58 to weaviate
# Adding chunk 41 of 58 to weaviate
# Adding chunk 42 of 58 to weaviate
# Adding chunk 43 of 58 to weaviate
# Adding chunk 44 of 58 to weaviate
# Adding chunk 45 of 58 to weaviate
# Adding chunk 46 of 58 to weaviate
# Adding chunk 47 of 58 to weaviate
# Adding chunk 48 of 58 to weaviate
# Adding chunk 49 of 58 to weaviate
# Adding chunk 50 of 58 to weaviate
# Adding chunk 51 of 58 to weaviate
# Adding chunk 52 of 58 to weaviate
# Adding chunk 53 of 58 to weaviate
# Adding chunk 54 of 58 to weaviate
# Adding chunk 55 of 58 to weaviate
# Adding chunk 56 of 58 to weaviate
# Adding chunk 57 of 58 to weaviate
#
#
# results/1ps9S0TaMC02NahJAfp3NyZo6NVmf7rpM-COVID-19 Accelerates Quantum Computing Adoption, Driving Robust Growth in North America, Europe, and Asia-Pacific.pdf.json is succesfully processed.
# Adding chunk 0 of 31 to weaviate
# Adding chunk 1 of 31 to weaviate
# Adding chunk 2 of 31 to weaviate
# Adding chunk 3 of 31 to weaviate
# Adding chunk 4 of 31 to weaviate
# Adding chunk 5 of 31 to weaviate
# Adding chunk 6 of 31 to weaviate
# Adding chunk 7 of 31 to weaviate
# Adding chunk 8 of 31 to weaviate
# Adding chunk 9 of 31 to weaviate
# Adding chunk 10 of 31 to weaviate
# Adding chunk 11 of 31 to weaviate
# Adding chunk 12 of 31 to weaviate
# Adding chunk 13 of 31 to weaviate
# Adding chunk 14 of 31 to weaviate
# Adding chunk 15 of 31 to weaviate
# Adding chunk 16 of 31 to weaviate
# Adding chunk 17 of 31 to weaviate
# Adding chunk 18 of 31 to weaviate
# Adding chunk 19 of 31 to weaviate
# Adding chunk 20 of 31 to weaviate
# Adding chunk 21 of 31 to weaviate
# Adding chunk 22 of 31 to weaviate
# Adding chunk 23 of 31 to weaviate
# Adding chunk 24 of 31 to weaviate
# Adding chunk 25 of 31 to weaviate
# Adding chunk 26 of 31 to weaviate
# Adding chunk 27 of 31 to weaviate
# Adding chunk 28 of 31 to weaviate
# Adding chunk 29 of 31 to weaviate
# Adding chunk 30 of 31 to weaviate
#
#
# results/1TwH2WPshvwueAHlDiMfe9STLtFgOx-uB-NASA's SpaceX Crew-7 Launches to International Space Station.pdf.json is succesfully processed.
# Adding chunk 0 of 38 to weaviate
# Adding chunk 1 of 38 to weaviate
# Adding chunk 2 of 38 to weaviate
# Adding chunk 3 of 38 to weaviate
# Adding chunk 4 of 38 to weaviate
# Adding chunk 5 of 38 to weaviate
# Adding chunk 6 of 38 to weaviate
# Adding chunk 7 of 38 to weaviate
# Adding chunk 8 of 38 to weaviate
# Adding chunk 9 of 38 to weaviate
# Adding chunk 10 of 38 to weaviate
# Adding chunk 11 of 38 to weaviate
# Adding chunk 12 of 38 to weaviate
# Adding chunk 13 of 38 to weaviate
# Adding chunk 14 of 38 to weaviate
# Adding chunk 15 of 38 to weaviate
# Adding chunk 16 of 38 to weaviate
# Adding chunk 17 of 38 to weaviate
# Adding chunk 18 of 38 to weaviate
# Adding chunk 19 of 38 to weaviate
# Adding chunk 20 of 38 to weaviate
# Adding chunk 21 of 38 to weaviate
# Adding chunk 22 of 38 to weaviate
# Adding chunk 23 of 38 to weaviate
# Adding chunk 24 of 38 to weaviate
# Adding chunk 25 of 38 to weaviate
# Adding chunk 26 of 38 to weaviate
# Adding chunk 27 of 38 to weaviate
# Adding chunk 28 of 38 to weaviate
# Adding chunk 29 of 38 to weaviate
# Adding chunk 30 of 38 to weaviate
# Adding chunk 31 of 38 to weaviate
# Adding chunk 32 of 38 to weaviate
# Adding chunk 33 of 38 to weaviate
# Adding chunk 34 of 38 to weaviate
# Adding chunk 35 of 38 to weaviate
# Adding chunk 36 of 38 to weaviate
# Adding chunk 37 of 38 to weaviate
#
#
# results/1AahuJfN_mmiqqP5E9byMj3cQBZJCanqmZW-YDSaCPC4-Quantum Photonics Market.docx.json is succesfully processed.
# Adding chunk 0 of 20 to weaviate
# Adding chunk 1 of 20 to weaviate
# Adding chunk 2 of 20 to weaviate
# Adding chunk 3 of 20 to weaviate
# Adding chunk 4 of 20 to weaviate
# Adding chunk 5 of 20 to weaviate
# Adding chunk 6 of 20 to weaviate
# Adding chunk 7 of 20 to weaviate
# Adding chunk 8 of 20 to weaviate
# Adding chunk 9 of 20 to weaviate
# Adding chunk 10 of 20 to weaviate
# Adding chunk 11 of 20 to weaviate
# Adding chunk 12 of 20 to weaviate
# Adding chunk 13 of 20 to weaviate
# Adding chunk 14 of 20 to weaviate
# Adding chunk 15 of 20 to weaviate
# Adding chunk 16 of 20 to weaviate
# Adding chunk 17 of 20 to weaviate
# Adding chunk 18 of 20 to weaviate
# Adding chunk 19 of 20 to weaviate
#
#
# results/180MZG3uAnSsSUbWtTqm2Gmv4GYpe2dnY-honeywell-quantum-encryption.docx.json is succesfully processed.
# Adding chunk 0 of 11 to weaviate
# Adding chunk 1 of 11 to weaviate
# Adding chunk 2 of 11 to weaviate
# Adding chunk 3 of 11 to weaviate
# Adding chunk 4 of 11 to weaviate
# Adding chunk 5 of 11 to weaviate
# Adding chunk 6 of 11 to weaviate
# Adding chunk 7 of 11 to weaviate
# Adding chunk 8 of 11 to weaviate
# Adding chunk 9 of 11 to weaviate
# Adding chunk 10 of 11 to weaviate
#
#
# results/EmailMessage/02sHn00001EwshAIAR.json is succesfully processed.
# Adding chunk 0 of 7 to weaviate
# Adding chunk 1 of 7 to weaviate
# Adding chunk 2 of 7 to weaviate
# Adding chunk 3 of 7 to weaviate
# Adding chunk 4 of 7 to weaviate
# Adding chunk 5 of 7 to weaviate
# Adding chunk 6 of 7 to weaviate
#
#
# results/EmailMessage/02sHn00001EwshBIAR.json is succesfully processed.
# Adding chunk 0 of 7 to weaviate
# Adding chunk 1 of 7 to weaviate
# Adding chunk 2 of 7 to weaviate
# Adding chunk 3 of 7 to weaviate
# Adding chunk 4 of 7 to weaviate
# Adding chunk 5 of 7 to weaviate
# Adding chunk 6 of 7 to weaviate
#
#
# results/EmailMessage/02sHn00001EwshFIAR.json is succesfully processed.
# Adding chunk 0 of 6 to weaviate
# Adding chunk 1 of 6 to weaviate
# Adding chunk 2 of 6 to weaviate
# Adding chunk 3 of 6 to weaviate
# Adding chunk 4 of 6 to weaviate
# Adding chunk 5 of 6 to weaviate
#
#
# results/EmailMessage/02sHn00001EwshtIAB.json is succesfully processed.
# Adding chunk 0 of 7 to weaviate
# Adding chunk 1 of 7 to weaviate
# Adding chunk 2 of 7 to weaviate
# Adding chunk 3 of 7 to weaviate
# Adding chunk 4 of 7 to weaviate
# Adding chunk 5 of 7 to weaviate
# Adding chunk 6 of 7 to weaviate
#
#
# results/Lead/00QHn000021npFsMAI.json is succesfully processed.
# Adding chunk 0 of 16 to weaviate
# Adding chunk 1 of 16 to weaviate
# Adding chunk 2 of 16 to weaviate
# Adding chunk 3 of 16 to weaviate
# Adding chunk 4 of 16 to weaviate
# Adding chunk 5 of 16 to weaviate
# Adding chunk 6 of 16 to weaviate
# Adding chunk 7 of 16 to weaviate
# Adding chunk 8 of 16 to weaviate
# Adding chunk 9 of 16 to weaviate
# Adding chunk 10 of 16 to weaviate
# Adding chunk 11 of 16 to weaviate
# Adding chunk 12 of 16 to weaviate
# Adding chunk 13 of 16 to weaviate
# Adding chunk 14 of 16 to weaviate
# Adding chunk 15 of 16 to weaviate
#
#
# results/Lead/00QHn000021npG6MAI.json is succesfully processed.
# Adding chunk 0 of 16 to weaviate
# Adding chunk 1 of 16 to weaviate
# Adding chunk 2 of 16 to weaviate
# Adding chunk 3 of 16 to weaviate
# Adding chunk 4 of 16 to weaviate
# Adding chunk 5 of 16 to weaviate
# Adding chunk 6 of 16 to weaviate
# Adding chunk 7 of 16 to weaviate
# Adding chunk 8 of 16 to weaviate
# Adding chunk 9 of 16 to weaviate
# Adding chunk 10 of 16 to weaviate
# Adding chunk 11 of 16 to weaviate
# Adding chunk 12 of 16 to weaviate
# Adding chunk 13 of 16 to weaviate
# Adding chunk 14 of 16 to weaviate
# Adding chunk 15 of 16 to weaviate
#
#
# results/Lead/00QHn000021npFzMAI.json is succesfully processed.
# Adding chunk 0 of 17 to weaviate
# Adding chunk 1 of 17 to weaviate
# Adding chunk 2 of 17 to weaviate
# Adding chunk 3 of 17 to weaviate
# Adding chunk 4 of 17 to weaviate
# Adding chunk 5 of 17 to weaviate
# Adding chunk 6 of 17 to weaviate
# Adding chunk 7 of 17 to weaviate
# Adding chunk 8 of 17 to weaviate
# Adding chunk 9 of 17 to weaviate
# Adding chunk 10 of 17 to weaviate
# Adding chunk 11 of 17 to weaviate
# Adding chunk 12 of 17 to weaviate
# Adding chunk 13 of 17 to weaviate
# Adding chunk 14 of 17 to weaviate
# Adding chunk 15 of 17 to weaviate
# Adding chunk 16 of 17 to weaviate
#
#
# results/Lead/00QHn000021npFoMAI.json is succesfully processed.
# Adding chunk 0 of 16 to weaviate
# Adding chunk 1 of 16 to weaviate
# Adding chunk 2 of 16 to weaviate
# Adding chunk 3 of 16 to weaviate
# Adding chunk 4 of 16 to weaviate
# Adding chunk 5 of 16 to weaviate
# Adding chunk 6 of 16 to weaviate
# Adding chunk 7 of 16 to weaviate
# Adding chunk 8 of 16 to weaviate
# Adding chunk 9 of 16 to weaviate
# Adding chunk 10 of 16 to weaviate
# Adding chunk 11 of 16 to weaviate
# Adding chunk 12 of 16 to weaviate
# Adding chunk 13 of 16 to weaviate
# Adding chunk 14 of 16 to weaviate
# Adding chunk 15 of 16 to weaviate
#
#
# results/Lead/00QHn000021npFnMAI.json is succesfully processed.
# Adding chunk 0 of 16 to weaviate
# Adding chunk 1 of 16 to weaviate
# Adding chunk 2 of 16 to weaviate
# Adding chunk 3 of 16 to weaviate
# Adding chunk 4 of 16 to weaviate
# Adding chunk 5 of 16 to weaviate
# Adding chunk 6 of 16 to weaviate
# Adding chunk 7 of 16 to weaviate
# Adding chunk 8 of 16 to weaviate
# Adding chunk 9 of 16 to weaviate
# Adding chunk 10 of 16 to weaviate
# Adding chunk 11 of 16 to weaviate
# Adding chunk 12 of 16 to weaviate
# Adding chunk 13 of 16 to weaviate
# Adding chunk 14 of 16 to weaviate
# Adding chunk 15 of 16 to weaviate
#
#
# results/Lead/00QHn000021npFrMAI.json is succesfully processed.
# Adding chunk 0 of 16 to weaviate
# Adding chunk 1 of 16 to weaviate
# Adding chunk 2 of 16 to weaviate
# Adding chunk 3 of 16 to weaviate
# Adding chunk 4 of 16 to weaviate
# Adding chunk 5 of 16 to weaviate
# Adding chunk 6 of 16 to weaviate
# Adding chunk 7 of 16 to weaviate
# Adding chunk 8 of 16 to weaviate
# Adding chunk 9 of 16 to weaviate
# Adding chunk 10 of 16 to weaviate
# Adding chunk 11 of 16 to weaviate
# Adding chunk 12 of 16 to weaviate
# Adding chunk 13 of 16 to weaviate
# Adding chunk 14 of 16 to weaviate
# Adding chunk 15 of 16 to weaviate
#
#
# results/Lead/00QHn000021npG7MAI.json is succesfully processed.
# Adding chunk 0 of 16 to weaviate
# Adding chunk 1 of 16 to weaviate
# Adding chunk 2 of 16 to weaviate
# Adding chunk 3 of 16 to weaviate
# Adding chunk 4 of 16 to weaviate
# Adding chunk 5 of 16 to weaviate
# Adding chunk 6 of 16 to weaviate
# Adding chunk 7 of 16 to weaviate
# Adding chunk 8 of 16 to weaviate
# Adding chunk 9 of 16 to weaviate
# Adding chunk 10 of 16 to weaviate
# Adding chunk 11 of 16 to weaviate
# Adding chunk 12 of 16 to weaviate
# Adding chunk 13 of 16 to weaviate
# Adding chunk 14 of 16 to weaviate
# Adding chunk 15 of 16 to weaviate
#
#
# results/Lead/00QHn000021npFyMAI.json is succesfully processed.
# Adding chunk 0 of 16 to weaviate
# Adding chunk 1 of 16 to weaviate
# Adding chunk 2 of 16 to weaviate
# Adding chunk 3 of 16 to weaviate
# Adding chunk 4 of 16 to weaviate
# Adding chunk 5 of 16 to weaviate
# Adding chunk 6 of 16 to weaviate
# Adding chunk 7 of 16 to weaviate
# Adding chunk 8 of 16 to weaviate
# Adding chunk 9 of 16 to weaviate
# Adding chunk 10 of 16 to weaviate
# Adding chunk 11 of 16 to weaviate
# Adding chunk 12 of 16 to weaviate
# Adding chunk 13 of 16 to weaviate
# Adding chunk 14 of 16 to weaviate
# Adding chunk 15 of 16 to weaviate
#
#
# results/Lead/00QHn000021npFpMAI.json is succesfully processed.
# Adding chunk 0 of 16 to weaviate
# Adding chunk 1 of 16 to weaviate
# Adding chunk 2 of 16 to weaviate
# Adding chunk 3 of 16 to weaviate
# Adding chunk 4 of 16 to weaviate
# Adding chunk 5 of 16 to weaviate
# Adding chunk 6 of 16 to weaviate
# Adding chunk 7 of 16 to weaviate
# Adding chunk 8 of 16 to weaviate
# Adding chunk 9 of 16 to weaviate
# Adding chunk 10 of 16 to weaviate
# Adding chunk 11 of 16 to weaviate
# Adding chunk 12 of 16 to weaviate
# Adding chunk 13 of 16 to weaviate
# Adding chunk 14 of 16 to weaviate
# Adding chunk 15 of 16 to weaviate
#
#
# results/Lead/00QHn000021npG5MAI.json is succesfully processed.
# Adding chunk 0 of 16 to weaviate
# Adding chunk 1 of 16 to weaviate
# Adding chunk 2 of 16 to weaviate
# Adding chunk 3 of 16 to weaviate
# Adding chunk 4 of 16 to weaviate
# Adding chunk 5 of 16 to weaviate
# Adding chunk 6 of 16 to weaviate
# Adding chunk 7 of 16 to weaviate
# Adding chunk 8 of 16 to weaviate
# Adding chunk 9 of 16 to weaviate
# Adding chunk 10 of 16 to weaviate
# Adding chunk 11 of 16 to weaviate
# Adding chunk 12 of 16 to weaviate
# Adding chunk 13 of 16 to weaviate
# Adding chunk 14 of 16 to weaviate
# Adding chunk 15 of 16 to weaviate
#
#
# results/Lead/00QHn000021npFqMAI.json is succesfully processed.
# Adding chunk 0 of 16 to weaviate
# Adding chunk 1 of 16 to weaviate
# Adding chunk 2 of 16 to weaviate
# Adding chunk 3 of 16 to weaviate
# Adding chunk 4 of 16 to weaviate
# Adding chunk 5 of 16 to weaviate
# Adding chunk 6 of 16 to weaviate
# Adding chunk 7 of 16 to weaviate
# Adding chunk 8 of 16 to weaviate
# Adding chunk 9 of 16 to weaviate
# Adding chunk 10 of 16 to weaviate
# Adding chunk 11 of 16 to weaviate
# Adding chunk 12 of 16 to weaviate
# Adding chunk 13 of 16 to weaviate
# Adding chunk 14 of 16 to weaviate
# Adding chunk 15 of 16 to weaviate
#
#
# results/Lead/00QHn000021npG4MAI.json is succesfully processed.
# Adding chunk 0 of 16 to weaviate
# Adding chunk 1 of 16 to weaviate
# Adding chunk 2 of 16 to weaviate
# Adding chunk 3 of 16 to weaviate
# Adding chunk 4 of 16 to weaviate
# Adding chunk 5 of 16 to weaviate
# Adding chunk 6 of 16 to weaviate
# Adding chunk 7 of 16 to weaviate
# Adding chunk 8 of 16 to weaviate
# Adding chunk 9 of 16 to weaviate
# Adding chunk 10 of 16 to weaviate
# Adding chunk 11 of 16 to weaviate
# Adding chunk 12 of 16 to weaviate
# Adding chunk 13 of 16 to weaviate
# Adding chunk 14 of 16 to weaviate
# Adding chunk 15 of 16 to weaviate
#
#
# results/Lead/00QHn000021npFxMAI.json is succesfully processed.
# Adding chunk 0 of 16 to weaviate
# Adding chunk 1 of 16 to weaviate
# Adding chunk 2 of 16 to weaviate
# Adding chunk 3 of 16 to weaviate
# Adding chunk 4 of 16 to weaviate
# Adding chunk 5 of 16 to weaviate
# Adding chunk 6 of 16 to weaviate
# Adding chunk 7 of 16 to weaviate
# Adding chunk 8 of 16 to weaviate
# Adding chunk 9 of 16 to weaviate
# Adding chunk 10 of 16 to weaviate
# Adding chunk 11 of 16 to weaviate
# Adding chunk 12 of 16 to weaviate
# Adding chunk 13 of 16 to weaviate
# Adding chunk 14 of 16 to weaviate
# Adding chunk 15 of 16 to weaviate
#
#
# results/Lead/00QHn000021npG8MAI.json is succesfully processed.
# Adding chunk 0 of 16 to weaviate
# Adding chunk 1 of 16 to weaviate
# Adding chunk 2 of 16 to weaviate
# Adding chunk 3 of 16 to weaviate
# Adding chunk 4 of 16 to weaviate
# Adding chunk 5 of 16 to weaviate
# Adding chunk 6 of 16 to weaviate
# Adding chunk 7 of 16 to weaviate
# Adding chunk 8 of 16 to weaviate
# Adding chunk 9 of 16 to weaviate
# Adding chunk 10 of 16 to weaviate
# Adding chunk 11 of 16 to weaviate
# Adding chunk 12 of 16 to weaviate
# Adding chunk 13 of 16 to weaviate
# Adding chunk 14 of 16 to weaviate
# Adding chunk 15 of 16 to weaviate
#
#
# results/Lead/00QHn000021npG1MAI.json is succesfully processed.
# Adding chunk 0 of 16 to weaviate
# Adding chunk 1 of 16 to weaviate
# Adding chunk 2 of 16 to weaviate
# Adding chunk 3 of 16 to weaviate
# Adding chunk 4 of 16 to weaviate
# Adding chunk 5 of 16 to weaviate
# Adding chunk 6 of 16 to weaviate
# Adding chunk 7 of 16 to weaviate
# Adding chunk 8 of 16 to weaviate
# Adding chunk 9 of 16 to weaviate
# Adding chunk 10 of 16 to weaviate
# Adding chunk 11 of 16 to weaviate
# Adding chunk 12 of 16 to weaviate
# Adding chunk 13 of 16 to weaviate
# Adding chunk 14 of 16 to weaviate
# Adding chunk 15 of 16 to weaviate
#
#
# results/Lead/00QHn000021npFtMAI.json is succesfully processed.
# Adding chunk 0 of 16 to weaviate
# Adding chunk 1 of 16 to weaviate
# Adding chunk 2 of 16 to weaviate
# Adding chunk 3 of 16 to weaviate
# Adding chunk 4 of 16 to weaviate
# Adding chunk 5 of 16 to weaviate
# Adding chunk 6 of 16 to weaviate
# Adding chunk 7 of 16 to weaviate
# Adding chunk 8 of 16 to weaviate
# Adding chunk 9 of 16 to weaviate
# Adding chunk 10 of 16 to weaviate
# Adding chunk 11 of 16 to weaviate
# Adding chunk 12 of 16 to weaviate
# Adding chunk 13 of 16 to weaviate
# Adding chunk 14 of 16 to weaviate
# Adding chunk 15 of 16 to weaviate
#
#
# results/Lead/00QHn000021npG0MAI.json is succesfully processed.
# Adding chunk 0 of 16 to weaviate
# Adding chunk 1 of 16 to weaviate
# Adding chunk 2 of 16 to weaviate
# Adding chunk 3 of 16 to weaviate
# Adding chunk 4 of 16 to weaviate
# Adding chunk 5 of 16 to weaviate
# Adding chunk 6 of 16 to weaviate
# Adding chunk 7 of 16 to weaviate
# Adding chunk 8 of 16 to weaviate
# Adding chunk 9 of 16 to weaviate
# Adding chunk 10 of 16 to weaviate
# Adding chunk 11 of 16 to weaviate
# Adding chunk 12 of 16 to weaviate
# Adding chunk 13 of 16 to weaviate
# Adding chunk 14 of 16 to weaviate
# Adding chunk 15 of 16 to weaviate
#
#
# results/Lead/00QHn000021npFuMAI.json is succesfully processed.
# Adding chunk 0 of 16 to weaviate
# Adding chunk 1 of 16 to weaviate
# Adding chunk 2 of 16 to weaviate
# Adding chunk 3 of 16 to weaviate
# Adding chunk 4 of 16 to weaviate
# Adding chunk 5 of 16 to weaviate
# Adding chunk 6 of 16 to weaviate
# Adding chunk 7 of 16 to weaviate
# Adding chunk 8 of 16 to weaviate
# Adding chunk 9 of 16 to weaviate
# Adding chunk 10 of 16 to weaviate
# Adding chunk 11 of 16 to weaviate
# Adding chunk 12 of 16 to weaviate
# Adding chunk 13 of 16 to weaviate
# Adding chunk 14 of 16 to weaviate
# Adding chunk 15 of 16 to weaviate
#
#
# results/Lead/00QHn000021npG2MAI.json is succesfully processed.
# Adding chunk 0 of 16 to weaviate
# Adding chunk 1 of 16 to weaviate
# Adding chunk 2 of 16 to weaviate
# Adding chunk 3 of 16 to weaviate
# Adding chunk 4 of 16 to weaviate
# Adding chunk 5 of 16 to weaviate
# Adding chunk 6 of 16 to weaviate
# Adding chunk 7 of 16 to weaviate
# Adding chunk 8 of 16 to weaviate
# Adding chunk 9 of 16 to weaviate
# Adding chunk 10 of 16 to weaviate
# Adding chunk 11 of 16 to weaviate
# Adding chunk 12 of 16 to weaviate
# Adding chunk 13 of 16 to weaviate
# Adding chunk 14 of 16 to weaviate
# Adding chunk 15 of 16 to weaviate
#
#
# results/Lead/00QHn000021npFwMAI.json is succesfully processed.
# Adding chunk 0 of 16 to weaviate
# Adding chunk 1 of 16 to weaviate
# Adding chunk 2 of 16 to weaviate
# Adding chunk 3 of 16 to weaviate
# Adding chunk 4 of 16 to weaviate
# Adding chunk 5 of 16 to weaviate
# Adding chunk 6 of 16 to weaviate
# Adding chunk 7 of 16 to weaviate
# Adding chunk 8 of 16 to weaviate
# Adding chunk 9 of 16 to weaviate
# Adding chunk 10 of 16 to weaviate
# Adding chunk 11 of 16 to weaviate
# Adding chunk 12 of 16 to weaviate
# Adding chunk 13 of 16 to weaviate
# Adding chunk 14 of 16 to weaviate
# Adding chunk 15 of 16 to weaviate
#
#
# results/Lead/00QHn000021npG3MAI.json is succesfully processed.
# Adding chunk 0 of 16 to weaviate
# Adding chunk 1 of 16 to weaviate
# Adding chunk 2 of 16 to weaviate
# Adding chunk 3 of 16 to weaviate
# Adding chunk 4 of 16 to weaviate
# Adding chunk 5 of 16 to weaviate
# Adding chunk 6 of 16 to weaviate
# Adding chunk 7 of 16 to weaviate
# Adding chunk 8 of 16 to weaviate
# Adding chunk 9 of 16 to weaviate
# Adding chunk 10 of 16 to weaviate
# Adding chunk 11 of 16 to weaviate
# Adding chunk 12 of 16 to weaviate
# Adding chunk 13 of 16 to weaviate
# Adding chunk 14 of 16 to weaviate
# Adding chunk 15 of 16 to weaviate
#
#
# results/Lead/00QHn000021npFvMAI.json is succesfully processed.
# Adding chunk 0 of 16 to weaviate
# Adding chunk 1 of 16 to weaviate
# Adding chunk 2 of 16 to weaviate
# Adding chunk 3 of 16 to weaviate
# Adding chunk 4 of 16 to weaviate
# Adding chunk 5 of 16 to weaviate
# Adding chunk 6 of 16 to weaviate
# Adding chunk 7 of 16 to weaviate
# Adding chunk 8 of 16 to weaviate
# Adding chunk 9 of 16 to weaviate
# Adding chunk 10 of 16 to weaviate
# Adding chunk 11 of 16 to weaviate
# Adding chunk 12 of 16 to weaviate
# Adding chunk 13 of 16 to weaviate
# Adding chunk 14 of 16 to weaviate
# Adding chunk 15 of 16 to weaviate
#
#
# results/Campaign/701Hn000001dWeWIAU.json is succesfully processed.
# Adding chunk 0 of 10 to weaviate
# Adding chunk 1 of 10 to weaviate
# Adding chunk 2 of 10 to weaviate
# Adding chunk 3 of 10 to weaviate
# Adding chunk 4 of 10 to weaviate
# Adding chunk 5 of 10 to weaviate
# Adding chunk 6 of 10 to weaviate
# Adding chunk 7 of 10 to weaviate
# Adding chunk 8 of 10 to weaviate
# Adding chunk 9 of 10 to weaviate
#
#
# results/Campaign/701Hn000001dWeZIAU.json is succesfully processed.
# Adding chunk 0 of 10 to weaviate
# Adding chunk 1 of 10 to weaviate
# Adding chunk 2 of 10 to weaviate
# Adding chunk 3 of 10 to weaviate
# Adding chunk 4 of 10 to weaviate
# Adding chunk 5 of 10 to weaviate
# Adding chunk 6 of 10 to weaviate
# Adding chunk 7 of 10 to weaviate
# Adding chunk 8 of 10 to weaviate
# Adding chunk 9 of 10 to weaviate
#
#
# results/Campaign/701Hn000001dWeXIAU.json is succesfully processed.
# Adding chunk 0 of 10 to weaviate
# Adding chunk 1 of 10 to weaviate
# Adding chunk 2 of 10 to weaviate
# Adding chunk 3 of 10 to weaviate
# Adding chunk 4 of 10 to weaviate
# Adding chunk 5 of 10 to weaviate
# Adding chunk 6 of 10 to weaviate
# Adding chunk 7 of 10 to weaviate
# Adding chunk 8 of 10 to weaviate
# Adding chunk 9 of 10 to weaviate
#
#
# results/Campaign/701Hn000001dWeYIAU.json is succesfully processed.
# Adding chunk 0 of 10 to weaviate
# Adding chunk 1 of 10 to weaviate
# Adding chunk 2 of 10 to weaviate
# Adding chunk 3 of 10 to weaviate
# Adding chunk 4 of 10 to weaviate
# Adding chunk 5 of 10 to weaviate
# Adding chunk 6 of 10 to weaviate
# Adding chunk 7 of 10 to weaviate
# Adding chunk 8 of 10 to weaviate
# Adding chunk 9 of 10 to weaviate
#
#
# results/Case/500Hn00001bslfuIAA.json is succesfully processed.
# Adding chunk 0 of 10 to weaviate
# Adding chunk 1 of 10 to weaviate
# Adding chunk 2 of 10 to weaviate
# Adding chunk 3 of 10 to weaviate
# Adding chunk 4 of 10 to weaviate
# Adding chunk 5 of 10 to weaviate
# Adding chunk 6 of 10 to weaviate
# Adding chunk 7 of 10 to weaviate
# Adding chunk 8 of 10 to weaviate
# Adding chunk 9 of 10 to weaviate
#
#
# results/Case/500Hn00001bslg0IAA.json is succesfully processed.
# Adding chunk 0 of 10 to weaviate
# Adding chunk 1 of 10 to weaviate
# Adding chunk 2 of 10 to weaviate
# Adding chunk 3 of 10 to weaviate
# Adding chunk 4 of 10 to weaviate
# Adding chunk 5 of 10 to weaviate
# Adding chunk 6 of 10 to weaviate
# Adding chunk 7 of 10 to weaviate
# Adding chunk 8 of 10 to weaviate
# Adding chunk 9 of 10 to weaviate
#
#
# results/Case/500Hn00001bslg9IAA.json is succesfully processed.
# Adding chunk 0 of 10 to weaviate
# Adding chunk 1 of 10 to weaviate
# Adding chunk 2 of 10 to weaviate
# Adding chunk 3 of 10 to weaviate
# Adding chunk 4 of 10 to weaviate
# Adding chunk 5 of 10 to weaviate
# Adding chunk 6 of 10 to weaviate
# Adding chunk 7 of 10 to weaviate
# Adding chunk 8 of 10 to weaviate
# Adding chunk 9 of 10 to weaviate
#
#
# results/Case/500Hn00001bslg8IAA.json is succesfully processed.
# Adding chunk 0 of 10 to weaviate
# Adding chunk 1 of 10 to weaviate
# Adding chunk 2 of 10 to weaviate
# Adding chunk 3 of 10 to weaviate
# Adding chunk 4 of 10 to weaviate
# Adding chunk 5 of 10 to weaviate
# Adding chunk 6 of 10 to weaviate
# Adding chunk 7 of 10 to weaviate
# Adding chunk 8 of 10 to weaviate
# Adding chunk 9 of 10 to weaviate
#
#
# results/Case/500Hn00001bslftIAA.json is succesfully processed.
# Adding chunk 0 of 10 to weaviate
# Adding chunk 1 of 10 to weaviate
# Adding chunk 2 of 10 to weaviate
# Adding chunk 3 of 10 to weaviate
# Adding chunk 4 of 10 to weaviate
# Adding chunk 5 of 10 to weaviate
# Adding chunk 6 of 10 to weaviate
# Adding chunk 7 of 10 to weaviate
# Adding chunk 8 of 10 to weaviate
# Adding chunk 9 of 10 to weaviate
#
#
# results/Case/500Hn00001bslg1IAA.json is succesfully processed.
# Adding chunk 0 of 10 to weaviate
# Adding chunk 1 of 10 to weaviate
# Adding chunk 2 of 10 to weaviate
# Adding chunk 3 of 10 to weaviate
# Adding chunk 4 of 10 to weaviate
# Adding chunk 5 of 10 to weaviate
# Adding chunk 6 of 10 to weaviate
# Adding chunk 7 of 10 to weaviate
# Adding chunk 8 of 10 to weaviate
# Adding chunk 9 of 10 to weaviate
#
#
# results/Case/500Hn00001bslfvIAA.json is succesfully processed.
# Adding chunk 0 of 9 to weaviate
# Adding chunk 1 of 9 to weaviate
# Adding chunk 2 of 9 to weaviate
# Adding chunk 3 of 9 to weaviate
# Adding chunk 4 of 9 to weaviate
# Adding chunk 5 of 9 to weaviate
# Adding chunk 6 of 9 to weaviate
# Adding chunk 7 of 9 to weaviate
# Adding chunk 8 of 9 to weaviate
#
#
# results/Case/500Hn00001bslg3IAA.json is succesfully processed.
# Adding chunk 0 of 10 to weaviate
# Adding chunk 1 of 10 to weaviate
# Adding chunk 2 of 10 to weaviate
# Adding chunk 3 of 10 to weaviate
# Adding chunk 4 of 10 to weaviate
# Adding chunk 5 of 10 to weaviate
# Adding chunk 6 of 10 to weaviate
# Adding chunk 7 of 10 to weaviate
# Adding chunk 8 of 10 to weaviate
# Adding chunk 9 of 10 to weaviate
#
#
# results/Case/500Hn00001bslfwIAA.json is succesfully processed.
# Adding chunk 0 of 10 to weaviate
# Adding chunk 1 of 10 to weaviate
# Adding chunk 2 of 10 to weaviate
# Adding chunk 3 of 10 to weaviate
# Adding chunk 4 of 10 to weaviate
# Adding chunk 5 of 10 to weaviate
# Adding chunk 6 of 10 to weaviate
# Adding chunk 7 of 10 to weaviate
# Adding chunk 8 of 10 to weaviate
# Adding chunk 9 of 10 to weaviate
#
#
# results/Case/500Hn00001bslg2IAA.json is succesfully processed.
# Adding chunk 0 of 10 to weaviate
# Adding chunk 1 of 10 to weaviate
# Adding chunk 2 of 10 to weaviate
# Adding chunk 3 of 10 to weaviate
# Adding chunk 4 of 10 to weaviate
# Adding chunk 5 of 10 to weaviate
# Adding chunk 6 of 10 to weaviate
# Adding chunk 7 of 10 to weaviate
# Adding chunk 8 of 10 to weaviate
# Adding chunk 9 of 10 to weaviate
#
#
# results/Case/500Hn00001bslfnIAA.json is succesfully processed.
# Adding chunk 0 of 9 to weaviate
# Adding chunk 1 of 9 to weaviate
# Adding chunk 2 of 9 to weaviate
# Adding chunk 3 of 9 to weaviate
# Adding chunk 4 of 9 to weaviate
# Adding chunk 5 of 9 to weaviate
# Adding chunk 6 of 9 to weaviate
# Adding chunk 7 of 9 to weaviate
# Adding chunk 8 of 9 to weaviate
#
#
# results/Case/500Hn00001bslg7IAA.json is succesfully processed.
# Adding chunk 0 of 10 to weaviate
# Adding chunk 1 of 10 to weaviate
# Adding chunk 2 of 10 to weaviate
# Adding chunk 3 of 10 to weaviate
# Adding chunk 4 of 10 to weaviate
# Adding chunk 5 of 10 to weaviate
# Adding chunk 6 of 10 to weaviate
# Adding chunk 7 of 10 to weaviate
# Adding chunk 8 of 10 to weaviate
# Adding chunk 9 of 10 to weaviate
#
#
# results/Case/500Hn00001bslgAIAQ.json is succesfully processed.
# Adding chunk 0 of 10 to weaviate
# Adding chunk 1 of 10 to weaviate
# Adding chunk 2 of 10 to weaviate
# Adding chunk 3 of 10 to weaviate
# Adding chunk 4 of 10 to weaviate
# Adding chunk 5 of 10 to weaviate
# Adding chunk 6 of 10 to weaviate
# Adding chunk 7 of 10 to weaviate
# Adding chunk 8 of 10 to weaviate
# Adding chunk 9 of 10 to weaviate
#
#
# results/Case/500Hn00001bslfrIAA.json is succesfully processed.
# Adding chunk 0 of 10 to weaviate
# Adding chunk 1 of 10 to weaviate
# Adding chunk 2 of 10 to weaviate
# Adding chunk 3 of 10 to weaviate
# Adding chunk 4 of 10 to weaviate
# Adding chunk 5 of 10 to weaviate
# Adding chunk 6 of 10 to weaviate
# Adding chunk 7 of 10 to weaviate
# Adding chunk 8 of 10 to weaviate
# Adding chunk 9 of 10 to weaviate
#
#
# results/Case/500Hn00001bslg6IAA.json is succesfully processed.
# Adding chunk 0 of 10 to weaviate
# Adding chunk 1 of 10 to weaviate
# Adding chunk 2 of 10 to weaviate
# Adding chunk 3 of 10 to weaviate
# Adding chunk 4 of 10 to weaviate
# Adding chunk 5 of 10 to weaviate
# Adding chunk 6 of 10 to weaviate
# Adding chunk 7 of 10 to weaviate
# Adding chunk 8 of 10 to weaviate
# Adding chunk 9 of 10 to weaviate
#
#
# results/Case/500Hn00001bslfsIAA.json is succesfully processed.
# Adding chunk 0 of 10 to weaviate
# Adding chunk 1 of 10 to weaviate
# Adding chunk 2 of 10 to weaviate
# Adding chunk 3 of 10 to weaviate
# Adding chunk 4 of 10 to weaviate
# Adding chunk 5 of 10 to weaviate
# Adding chunk 6 of 10 to weaviate
# Adding chunk 7 of 10 to weaviate
# Adding chunk 8 of 10 to weaviate
# Adding chunk 9 of 10 to weaviate
#
#
# results/Case/500Hn00001bslfzIAA.json is succesfully processed.
# Adding chunk 0 of 10 to weaviate
# Adding chunk 1 of 10 to weaviate
# Adding chunk 2 of 10 to weaviate
# Adding chunk 3 of 10 to weaviate
# Adding chunk 4 of 10 to weaviate
# Adding chunk 5 of 10 to weaviate
# Adding chunk 6 of 10 to weaviate
# Adding chunk 7 of 10 to weaviate
# Adding chunk 8 of 10 to weaviate
# Adding chunk 9 of 10 to weaviate
#
#
# results/Case/500Hn00001bslfoIAA.json is succesfully processed.
# Adding chunk 0 of 10 to weaviate
# Adding chunk 1 of 10 to weaviate
# Adding chunk 2 of 10 to weaviate
# Adding chunk 3 of 10 to weaviate
# Adding chunk 4 of 10 to weaviate
# Adding chunk 5 of 10 to weaviate
# Adding chunk 6 of 10 to weaviate
# Adding chunk 7 of 10 to weaviate
# Adding chunk 8 of 10 to weaviate
# Adding chunk 9 of 10 to weaviate
#
#
# results/Case/500Hn00001bslg4IAA.json is succesfully processed.
# Adding chunk 0 of 10 to weaviate
# Adding chunk 1 of 10 to weaviate
# Adding chunk 2 of 10 to weaviate
# Adding chunk 3 of 10 to weaviate
# Adding chunk 4 of 10 to weaviate
# Adding chunk 5 of 10 to weaviate
# Adding chunk 6 of 10 to weaviate
# Adding chunk 7 of 10 to weaviate
# Adding chunk 8 of 10 to weaviate
# Adding chunk 9 of 10 to weaviate
#
#
# results/Case/500Hn00001bslfqIAA.json is succesfully processed.
# Adding chunk 0 of 10 to weaviate
# Adding chunk 1 of 10 to weaviate
# Adding chunk 2 of 10 to weaviate
# Adding chunk 3 of 10 to weaviate
# Adding chunk 4 of 10 to weaviate
# Adding chunk 5 of 10 to weaviate
# Adding chunk 6 of 10 to weaviate
# Adding chunk 7 of 10 to weaviate
# Adding chunk 8 of 10 to weaviate
# Adding chunk 9 of 10 to weaviate
#
#
# results/Case/500Hn00001bslgBIAQ.json is succesfully processed.
# Adding chunk 0 of 10 to weaviate
# Adding chunk 1 of 10 to weaviate
# Adding chunk 2 of 10 to weaviate
# Adding chunk 3 of 10 to weaviate
# Adding chunk 4 of 10 to weaviate
# Adding chunk 5 of 10 to weaviate
# Adding chunk 6 of 10 to weaviate
# Adding chunk 7 of 10 to weaviate
# Adding chunk 8 of 10 to weaviate
# Adding chunk 9 of 10 to weaviate
#
#
# results/Case/500Hn00001bslfmIAA.json is succesfully processed.
# Adding chunk 0 of 10 to weaviate
# Adding chunk 1 of 10 to weaviate
# Adding chunk 2 of 10 to weaviate
# Adding chunk 3 of 10 to weaviate
# Adding chunk 4 of 10 to weaviate
# Adding chunk 5 of 10 to weaviate
# Adding chunk 6 of 10 to weaviate
# Adding chunk 7 of 10 to weaviate
# Adding chunk 8 of 10 to weaviate
# Adding chunk 9 of 10 to weaviate
#
#
# results/Case/500Hn00001bslfxIAA.json is succesfully processed.
# Adding chunk 0 of 10 to weaviate
# Adding chunk 1 of 10 to weaviate
# Adding chunk 2 of 10 to weaviate
# Adding chunk 3 of 10 to weaviate
# Adding chunk 4 of 10 to weaviate
# Adding chunk 5 of 10 to weaviate
# Adding chunk 6 of 10 to weaviate
# Adding chunk 7 of 10 to weaviate
# Adding chunk 8 of 10 to weaviate
# Adding chunk 9 of 10 to weaviate
#
#
# results/Case/500Hn00001bslfyIAA.json is succesfully processed.
# Adding chunk 0 of 9 to weaviate
# Adding chunk 1 of 9 to weaviate
# Adding chunk 2 of 9 to weaviate
# Adding chunk 3 of 9 to weaviate
# Adding chunk 4 of 9 to weaviate
# Adding chunk 5 of 9 to weaviate
# Adding chunk 6 of 9 to weaviate
# Adding chunk 7 of 9 to weaviate
# Adding chunk 8 of 9 to weaviate
#
#
# results/Case/500Hn00001bslg5IAA.json is succesfully processed.
# Adding chunk 0 of 10 to weaviate
# Adding chunk 1 of 10 to weaviate
# Adding chunk 2 of 10 to weaviate
# Adding chunk 3 of 10 to weaviate
# Adding chunk 4 of 10 to weaviate
# Adding chunk 5 of 10 to weaviate
# Adding chunk 6 of 10 to weaviate
# Adding chunk 7 of 10 to weaviate
# Adding chunk 8 of 10 to weaviate
# Adding chunk 9 of 10 to weaviate
#
#
# results/Case/500Hn00001bslfpIAA.json is succesfully processed.
# Adding chunk 0 of 10 to weaviate
# Adding chunk 1 of 10 to weaviate
# Adding chunk 2 of 10 to weaviate
# Adding chunk 3 of 10 to weaviate
# Adding chunk 4 of 10 to weaviate
# Adding chunk 5 of 10 to weaviate
# Adding chunk 6 of 10 to weaviate
# Adding chunk 7 of 10 to weaviate
# Adding chunk 8 of 10 to weaviate
# Adding chunk 9 of 10 to weaviate
#
#
# results/Account/001Hn00001wCnWKIA0.json is succesfully processed.
# Adding chunk 0 of 22 to weaviate
# Adding chunk 1 of 22 to weaviate
# Adding chunk 2 of 22 to weaviate
# Adding chunk 3 of 22 to weaviate
# Adding chunk 4 of 22 to weaviate
# Adding chunk 5 of 22 to weaviate
# Adding chunk 6 of 22 to weaviate
# Adding chunk 7 of 22 to weaviate
# Adding chunk 8 of 22 to weaviate
# Adding chunk 9 of 22 to weaviate
# Adding chunk 10 of 22 to weaviate
# Adding chunk 11 of 22 to weaviate
# Adding chunk 12 of 22 to weaviate
# Adding chunk 13 of 22 to weaviate
# Adding chunk 14 of 22 to weaviate
# Adding chunk 15 of 22 to weaviate
# Adding chunk 16 of 22 to weaviate
# Adding chunk 17 of 22 to weaviate
# Adding chunk 18 of 22 to weaviate
# Adding chunk 19 of 22 to weaviate
# Adding chunk 20 of 22 to weaviate
# Adding chunk 21 of 22 to weaviate
#
#
# results/Account/001Hn00001wCnWJIA0.json is succesfully processed.
# Adding chunk 0 of 19 to weaviate
# Adding chunk 1 of 19 to weaviate
# Adding chunk 2 of 19 to weaviate
# Adding chunk 3 of 19 to weaviate
# Adding chunk 4 of 19 to weaviate
# Adding chunk 5 of 19 to weaviate
# Adding chunk 6 of 19 to weaviate
# Adding chunk 7 of 19 to weaviate
# Adding chunk 8 of 19 to weaviate
# Adding chunk 9 of 19 to weaviate
# Adding chunk 10 of 19 to weaviate
# Adding chunk 11 of 19 to weaviate
# Adding chunk 12 of 19 to weaviate
# Adding chunk 13 of 19 to weaviate
# Adding chunk 14 of 19 to weaviate
# Adding chunk 15 of 19 to weaviate
# Adding chunk 16 of 19 to weaviate
# Adding chunk 17 of 19 to weaviate
# Adding chunk 18 of 19 to weaviate
#
#
# results/Account/001Hn00001wCnWTIA0.json is succesfully processed.
# Adding chunk 0 of 19 to weaviate
# Adding chunk 1 of 19 to weaviate
# Adding chunk 2 of 19 to weaviate
# Adding chunk 3 of 19 to weaviate
# Adding chunk 4 of 19 to weaviate
# Adding chunk 5 of 19 to weaviate
# Adding chunk 6 of 19 to weaviate
# Adding chunk 7 of 19 to weaviate
# Adding chunk 8 of 19 to weaviate
# Adding chunk 9 of 19 to weaviate
# Adding chunk 10 of 19 to weaviate
# Adding chunk 11 of 19 to weaviate
# Adding chunk 12 of 19 to weaviate
# Adding chunk 13 of 19 to weaviate
# Adding chunk 14 of 19 to weaviate
# Adding chunk 15 of 19 to weaviate
# Adding chunk 16 of 19 to weaviate
# Adding chunk 17 of 19 to weaviate
# Adding chunk 18 of 19 to weaviate
#
#
# results/Account/001Hn00001wCnWIIA0.json is succesfully processed.
# Adding chunk 0 of 23 to weaviate
# Adding chunk 1 of 23 to weaviate
# Adding chunk 2 of 23 to weaviate
# Adding chunk 3 of 23 to weaviate
# Adding chunk 4 of 23 to weaviate
# Adding chunk 5 of 23 to weaviate
# Adding chunk 6 of 23 to weaviate
# Adding chunk 7 of 23 to weaviate
# Adding chunk 8 of 23 to weaviate
# Adding chunk 9 of 23 to weaviate
# Adding chunk 10 of 23 to weaviate
# Adding chunk 11 of 23 to weaviate
# Adding chunk 12 of 23 to weaviate
# Adding chunk 13 of 23 to weaviate
# Adding chunk 14 of 23 to weaviate
# Adding chunk 15 of 23 to weaviate
# Adding chunk 16 of 23 to weaviate
# Adding chunk 17 of 23 to weaviate
# Adding chunk 18 of 23 to weaviate
# Adding chunk 19 of 23 to weaviate
# Adding chunk 20 of 23 to weaviate
# Adding chunk 21 of 23 to weaviate
# Adding chunk 22 of 23 to weaviate
#
#
# results/Account/001Hn00001wCnWLIA0.json is succesfully processed.
# Adding chunk 0 of 22 to weaviate
# Adding chunk 1 of 22 to weaviate
# Adding chunk 2 of 22 to weaviate
# Adding chunk 3 of 22 to weaviate
# Adding chunk 4 of 22 to weaviate
# Adding chunk 5 of 22 to weaviate
# Adding chunk 6 of 22 to weaviate
# Adding chunk 7 of 22 to weaviate
# Adding chunk 8 of 22 to weaviate
# Adding chunk 9 of 22 to weaviate
# Adding chunk 10 of 22 to weaviate
# Adding chunk 11 of 22 to weaviate
# Adding chunk 12 of 22 to weaviate
# Adding chunk 13 of 22 to weaviate
# Adding chunk 14 of 22 to weaviate
# Adding chunk 15 of 22 to weaviate
# Adding chunk 16 of 22 to weaviate
# Adding chunk 17 of 22 to weaviate
# Adding chunk 18 of 22 to weaviate
# Adding chunk 19 of 22 to weaviate
# Adding chunk 20 of 22 to weaviate
# Adding chunk 21 of 22 to weaviate
#
#
# results/Account/001Hn00001wCnWPIA0.json is succesfully processed.
# Adding chunk 0 of 24 to weaviate
# Adding chunk 1 of 24 to weaviate
# Adding chunk 2 of 24 to weaviate
# Adding chunk 3 of 24 to weaviate
# Adding chunk 4 of 24 to weaviate
# Adding chunk 5 of 24 to weaviate
# Adding chunk 6 of 24 to weaviate
# Adding chunk 7 of 24 to weaviate
# Adding chunk 8 of 24 to weaviate
# Adding chunk 9 of 24 to weaviate
# Adding chunk 10 of 24 to weaviate
# Adding chunk 11 of 24 to weaviate
# Adding chunk 12 of 24 to weaviate
# Adding chunk 13 of 24 to weaviate
# Adding chunk 14 of 24 to weaviate
# Adding chunk 15 of 24 to weaviate
# Adding chunk 16 of 24 to weaviate
# Adding chunk 17 of 24 to weaviate
# Adding chunk 18 of 24 to weaviate
# Adding chunk 19 of 24 to weaviate
# Adding chunk 20 of 24 to weaviate
# Adding chunk 21 of 24 to weaviate
# Adding chunk 22 of 24 to weaviate
# Adding chunk 23 of 24 to weaviate
#
#
# results/Account/001Hn00001wCnWQIA0.json is succesfully processed.
# Adding chunk 0 of 22 to weaviate
# Adding chunk 1 of 22 to weaviate
# Adding chunk 2 of 22 to weaviate
# Adding chunk 3 of 22 to weaviate
# Adding chunk 4 of 22 to weaviate
# Adding chunk 5 of 22 to weaviate
# Adding chunk 6 of 22 to weaviate
# Adding chunk 7 of 22 to weaviate
# Adding chunk 8 of 22 to weaviate
# Adding chunk 9 of 22 to weaviate
# Adding chunk 10 of 22 to weaviate
# Adding chunk 11 of 22 to weaviate
# Adding chunk 12 of 22 to weaviate
# Adding chunk 13 of 22 to weaviate
# Adding chunk 14 of 22 to weaviate
# Adding chunk 15 of 22 to weaviate
# Adding chunk 16 of 22 to weaviate
# Adding chunk 17 of 22 to weaviate
# Adding chunk 18 of 22 to weaviate
# Adding chunk 19 of 22 to weaviate
# Adding chunk 20 of 22 to weaviate
# Adding chunk 21 of 22 to weaviate
#
#
# results/Account/001Hn00001wCnWMIA0.json is succesfully processed.
# Adding chunk 0 of 24 to weaviate
# Adding chunk 1 of 24 to weaviate
# Adding chunk 2 of 24 to weaviate
# Adding chunk 3 of 24 to weaviate
# Adding chunk 4 of 24 to weaviate
# Adding chunk 5 of 24 to weaviate
# Adding chunk 6 of 24 to weaviate
# Adding chunk 7 of 24 to weaviate
# Adding chunk 8 of 24 to weaviate
# Adding chunk 9 of 24 to weaviate
# Adding chunk 10 of 24 to weaviate
# Adding chunk 11 of 24 to weaviate
# Adding chunk 12 of 24 to weaviate
# Adding chunk 13 of 24 to weaviate
# Adding chunk 14 of 24 to weaviate
# Adding chunk 15 of 24 to weaviate
# Adding chunk 16 of 24 to weaviate
# Adding chunk 17 of 24 to weaviate
# Adding chunk 18 of 24 to weaviate
# Adding chunk 19 of 24 to weaviate
# Adding chunk 20 of 24 to weaviate
# Adding chunk 21 of 24 to weaviate
# Adding chunk 22 of 24 to weaviate
# Adding chunk 23 of 24 to weaviate
#
#
# results/Account/001Hn00001wCnWSIA0.json is succesfully processed.
# Adding chunk 0 of 23 to weaviate
# Adding chunk 1 of 23 to weaviate
# Adding chunk 2 of 23 to weaviate
# Adding chunk 3 of 23 to weaviate
# Adding chunk 4 of 23 to weaviate
# Adding chunk 5 of 23 to weaviate
# Adding chunk 6 of 23 to weaviate
# Adding chunk 7 of 23 to weaviate
# Adding chunk 8 of 23 to weaviate
# Adding chunk 9 of 23 to weaviate
# Adding chunk 10 of 23 to weaviate
# Adding chunk 11 of 23 to weaviate
# Adding chunk 12 of 23 to weaviate
# Adding chunk 13 of 23 to weaviate
# Adding chunk 14 of 23 to weaviate
# Adding chunk 15 of 23 to weaviate
# Adding chunk 16 of 23 to weaviate
# Adding chunk 17 of 23 to weaviate
# Adding chunk 18 of 23 to weaviate
# Adding chunk 19 of 23 to weaviate
# Adding chunk 20 of 23 to weaviate
# Adding chunk 21 of 23 to weaviate
# Adding chunk 22 of 23 to weaviate
#
#
# results/Account/001Hn00001wCnWOIA0.json is succesfully processed.
# Adding chunk 0 of 24 to weaviate
# Adding chunk 1 of 24 to weaviate
# Adding chunk 2 of 24 to weaviate
# Adding chunk 3 of 24 to weaviate
# Adding chunk 4 of 24 to weaviate
# Adding chunk 5 of 24 to weaviate
# Adding chunk 6 of 24 to weaviate
# Adding chunk 7 of 24 to weaviate
# Adding chunk 8 of 24 to weaviate
# Adding chunk 9 of 24 to weaviate
# Adding chunk 10 of 24 to weaviate
# Adding chunk 11 of 24 to weaviate
# Adding chunk 12 of 24 to weaviate
# Adding chunk 13 of 24 to weaviate
# Adding chunk 14 of 24 to weaviate
# Adding chunk 15 of 24 to weaviate
# Adding chunk 16 of 24 to weaviate
# Adding chunk 17 of 24 to weaviate
# Adding chunk 18 of 24 to weaviate
# Adding chunk 19 of 24 to weaviate
# Adding chunk 20 of 24 to weaviate
# Adding chunk 21 of 24 to weaviate
# Adding chunk 22 of 24 to weaviate
# Adding chunk 23 of 24 to weaviate
#
#
# results/Account/001Hn00001tJVo9IAG.json is succesfully processed.
# Adding chunk 0 of 16 to weaviate
# Adding chunk 1 of 16 to weaviate
# Adding chunk 2 of 16 to weaviate
# Adding chunk 3 of 16 to weaviate
# Adding chunk 4 of 16 to weaviate
# Adding chunk 5 of 16 to weaviate
# Adding chunk 6 of 16 to weaviate
# Adding chunk 7 of 16 to weaviate
# Adding chunk 8 of 16 to weaviate
# Adding chunk 9 of 16 to weaviate
# Adding chunk 10 of 16 to weaviate
# Adding chunk 11 of 16 to weaviate
# Adding chunk 12 of 16 to weaviate
# Adding chunk 13 of 16 to weaviate
# Adding chunk 14 of 16 to weaviate
# Adding chunk 15 of 16 to weaviate
#
#
# results/Account/001Hn00001wCnWNIA0.json is succesfully processed.
# Adding chunk 0 of 23 to weaviate
# Adding chunk 1 of 23 to weaviate
# Adding chunk 2 of 23 to weaviate
# Adding chunk 3 of 23 to weaviate
# Adding chunk 4 of 23 to weaviate
# Adding chunk 5 of 23 to weaviate
# Adding chunk 6 of 23 to weaviate
# Adding chunk 7 of 23 to weaviate
# Adding chunk 8 of 23 to weaviate
# Adding chunk 9 of 23 to weaviate
# Adding chunk 10 of 23 to weaviate
# Adding chunk 11 of 23 to weaviate
# Adding chunk 12 of 23 to weaviate
# Adding chunk 13 of 23 to weaviate
# Adding chunk 14 of 23 to weaviate
# Adding chunk 15 of 23 to weaviate
# Adding chunk 16 of 23 to weaviate
# Adding chunk 17 of 23 to weaviate
# Adding chunk 18 of 23 to weaviate
# Adding chunk 19 of 23 to weaviate
# Adding chunk 20 of 23 to weaviate
# Adding chunk 21 of 23 to weaviate
# Adding chunk 22 of 23 to weaviate
#
#
# results/Account/001Hn00001wCnWRIA0.json is succesfully processed.
# Adding chunk 0 of 22 to weaviate
# Adding chunk 1 of 22 to weaviate
# Adding chunk 2 of 22 to weaviate
# Adding chunk 3 of 22 to weaviate
# Adding chunk 4 of 22 to weaviate
# Adding chunk 5 of 22 to weaviate
# Adding chunk 6 of 22 to weaviate
# Adding chunk 7 of 22 to weaviate
# Adding chunk 8 of 22 to weaviate
# Adding chunk 9 of 22 to weaviate
# Adding chunk 10 of 22 to weaviate
# Adding chunk 11 of 22 to weaviate
# Adding chunk 12 of 22 to weaviate
# Adding chunk 13 of 22 to weaviate
# Adding chunk 14 of 22 to weaviate
# Adding chunk 15 of 22 to weaviate
# Adding chunk 16 of 22 to weaviate
# Adding chunk 17 of 22 to weaviate
# Adding chunk 18 of 22 to weaviate
# Adding chunk 19 of 22 to weaviate
# Adding chunk 20 of 22 to weaviate
# Adding chunk 21 of 22 to weaviate

# %%
# Query weaviate

def query_weaviate(client, query, limit: int = 10):
    return (
        client.query
        .get('Doc', ['text', 'last_modified'])
        .with_near_text({
            'concepts': [query]
        })
        .with_additional("distance")
        .with_limit(limit)
        .do()
    )

def print_query_and_results(query, results):
    print("\n\n\n-------------------------")
    print(f"query: {query}")
    print("-------------------------")
    for index, result in enumerate(results["data"]["Get"]["Doc"]):
        print(f"\n\n-- RESULT {index}:\n")
        print(result["text"])
        # print(result["text"].replace("\\n", "\n"), end="")

queries = [
    "Explore the significance of the Federal Reserve's inflation target and how it is explained.",
    "Look for information regarding the factors considered by the FOMC when it comes to maximum employment.",
    "Find mentions of commercial interest in post-quantum cryptography.",
    "Investigate any discussions or explanations regarding the significance and function of Shor's algorithm in quantum computing",

]

for query in queries:
    results = query_weaviate(client, query, limit=5)
    print_query_and_results(query, results)
# Out:
# -------------------------
# query: Explore the significance of the Federal Reserve's inflation target and how it is explained.
# -------------------------
#
#
# -- RESULT 0:
#
# One notable aspect is the FOMC's inflation target of 2 percent over the longer run. This symmetric inflation goal is communicated clearly to anchor longer-term inflation expectations, which can, in turn, influence price stability and long-term interest rates. Understanding how the Federal Reserve's inflation target aligns with our investment strategies could be crucial in navigating the financial markets.
#
#
# -- RESULT 1:
#
# One notable aspect is the FOMC's inflation target of 2 percent over the longer run. This symmetric inflation goal is communicated clearly to anchor longer-term inflation expectations, which can, in turn, influence price stability and long-term interest rates. Understanding how the Federal Reserve's inflation target aligns with our investment strategies could be crucial in navigating the financial markets.
#
#
# -- RESULT 2:
#
# It's essential that we stay informed about the Federal Reserve's monetary policy and how it might affect our investment strategies. I suggest we schedule a meeting to delve deeper into this topic and explore ways to adjust our investment approach accordingly.
#
#
# -- RESULT 3:
#
# It's essential that we stay informed about the Federal Reserve's monetary policy and how it might affect our investment strategies. I suggest we schedule a meeting to delve deeper into this topic and explore ways to adjust our investment approach accordingly.
#
#
# -- RESULT 4:
#
# I believe that staying informed about the Federal Reserve's monetary policy strategy and its implications for our investments is essential. Let's schedule a meeting to delve deeper into this topic and explore how we can align our strategies with the evolving economic landscape.
#
#
#
# -------------------------
# query: Look for information regarding the factors considered by the FOMC when it comes to maximum employment.
# -------------------------
#
#
# -- RESULT 0:
#
# Moreover, the FOMC considers a wide range of indicators when assessing maximum employment, recognizing that this assessment can be uncertain and subject to revision. Information about Committee participants' estimates of the longer-run normal rates of output growth and unemployment is published regularly. These estimates can provide valuable insights into the labor market and economic growth prospects.
#
#
# -- RESULT 1:
#
# Moreover, the FOMC considers a wide range of indicators when assessing maximum employment, recognizing that this assessment can be uncertain and subject to revision. Information about Committee participants' estimates of the longer-run normal rates of output growth and unemployment is published regularly. These estimates can provide valuable insights into the labor market and economic growth prospects.
#
#
# -- RESULT 2:
#
# Additionally, the FOMC's assessment of maximum employment takes into account a variety of indicators, recognizing the uncertainty in such assessments. These assessments can impact our understanding of the labor market and economic growth prospects.
#
#
# -- RESULT 3:
#
# Additionally, the FOMC's assessment of maximum employment takes into account a variety of indicators, recognizing the uncertainty in such assessments. These assessments can impact our understanding of the labor market and economic growth prospects.
#
#
# -- RESULT 4:
#
# The Federal Open Market Committee (FOMC) has laid out its commitment to achieving maximum employment, stable prices, and moderate long-term interest rates. They stress the importance of clear communication to reduce economic uncertainty and enhance transparency and accountability.
#
#
#
# -------------------------
# query: Find mentions of commercial interest in post-quantum cryptography.
# -------------------------
#
#
# -- RESULT 0:
#
# There's a growing interest in what's known as "post-quantum cryptography." These are cryptographic algorithms designed to resist attacks from quantum computers. Many experts predict that these algorithms will be standardized in the 2020s. Getting involved in the development and implementation of such algorithms could position us as leaders in the field of quantum-resistant cybersecurity.
#
#
# -- RESULT 1:
#
# There's a growing interest in what's known as "post-quantum cryptography." These are cryptographic algorithms designed to resist attacks from quantum computers. Many experts predict that these algorithms will be standardized in the 2020s. Getting involved in the development and implementation of such algorithms could position us as leaders in the field of quantum-resistant cybersecurity.
#
#
# -- RESULT 2:
#
# I believe that exploring opportunities in the realm of post-quantum cryptography aligns well with our business objectives and could give us a competitive edge in the evolving cybersecurity market. I'd love to discuss this further with you and explore how we can strategically position ourselves in this space.
#
#
# -- RESULT 3:
#
# I believe that exploring opportunities in the realm of post-quantum cryptography aligns well with our business objectives and could give us a competitive edge in the evolving cybersecurity market. I'd love to discuss this further with you and explore how we can strategically position ourselves in this space.
#
#
# -- RESULT 4:
#
# QUANTUM COMPUTERS AND CRYPTOGRAPHY
#
# Quantum computing will have a major impact on cryptography, which relies upon hard-to-compute problems to protect data. Shor’s algorithm running on a large quantum computer will greatly reduce the required computation (the workfactor) to extract the private key from the asymmetric ciphers used to protect almost all Internet trafﬁc and stored encrypted data. There is strong commercial interest in deploy- ing post-quantum cryptography well before such a quantum computer has been built. Companies and governments cannot afford to have their now-private communications decrypted in the future, even if that future is 30 years away. For this reason, there is a need to begin the transition to post-quantum cryptography as soon as possible, especially since it takes over a decade to make existing Web standards obsolete (see Section 4.4).
#
#
#
# -------------------------
# query: Investigate any discussions or explanations regarding the significance and function of Shor's algorithm in quantum computing
# -------------------------
#
#
# -- RESULT 0:
#
# Given the large risk a quantum computer poses to current protocols, there is an active effort to develop post-quantum cryptography, asymmet- ric ciphers that a quantum computer cannot defeat. These are likely to be standardized in the 2020s. While the potential utility of Shor’s algorithm for cracking deployed cryptography was a major driver of early enthu- siasm in quantum computing research, the existence of cryptographic algorithms that are believed to be quantum-resistant will reduce the use- fulness of a quantum computer for cryptanalysis and thus will reduce the extent to which this application will drive quantum computing R&D in the long term (see Section 4.3).
#
#
# -- RESULT 1:
#
# Given the large risk a quantum computer poses to current protocols, there is an active effort to develop post-quantum cryptography, asymmet- ric ciphers that a quantum computer cannot defeat. These are likely to be standardized in the 2020s. While the potential utility of Shor’s algorithm for cracking deployed cryptography was a major driver of early enthu- siasm in quantum computing research, the existence of cryptographic algorithms that are believed to be quantum-resistant will reduce the use- fulness of a quantum computer for cryptanalysis and thus will reduce the extent to which this application will drive quantum computing R&D in the long term (see Section 4.3).
#
#
# -- RESULT 2:
#
# QUANTUM COMPUTERS AND CRYPTOGRAPHY
#
# Quantum computing will have a major impact on cryptography, which relies upon hard-to-compute problems to protect data. Shor’s algorithm running on a large quantum computer will greatly reduce the required computation (the workfactor) to extract the private key from the asymmetric ciphers used to protect almost all Internet trafﬁc and stored encrypted data. There is strong commercial interest in deploy- ing post-quantum cryptography well before such a quantum computer has been built. Companies and governments cannot afford to have their now-private communications decrypted in the future, even if that future is 30 years away. For this reason, there is a need to begin the transition to post-quantum cryptography as soon as possible, especially since it takes over a decade to make existing Web standards obsolete (see Section 4.4).
#
#
# -- RESULT 3:
#
# QUANTUM COMPUTERS AND CRYPTOGRAPHY
#
# Quantum computing will have a major impact on cryptography, which relies upon hard-to-compute problems to protect data. Shor’s algorithm running on a large quantum computer will greatly reduce the required computation (the workfactor) to extract the private key from the asymmetric ciphers used to protect almost all Internet trafﬁc and stored encrypted data. There is strong commercial interest in deploy- ing post-quantum cryptography well before such a quantum computer has been built. Companies and governments cannot afford to have their now-private communications decrypted in the future, even if that future is 30 years away. For this reason, there is a need to begin the transition to post-quantum cryptography as soon as possible, especially since it takes over a decade to make existing Web standards obsolete (see Section 4.4).
#
#
# -- RESULT 4:
#
# Quantum Computing: Progress and Prospects
#
# Summary
#
# Quantum mechanics, the subﬁeld of physics that describes the behav- ior of very small particles, provides the basis for a new paradigm of computing. Quantum computing (QC) was ﬁrst proposed in the 1980s as a way to improve computational modeling of the behavior of very small (“quantum”) physical systems. Interest in the ﬁeld grew in the 1990s with the introduction of Shor’s algorithm, which, if implemented on a quantum computer, would exponentially speed up an important class of cryptanalysis and potentially threaten some of the cryptographic methods used to protect government and civilian communications and stored data. In fact, quantum computers are the only known model for computing that could offer exponential speedup over today’s computers.1
