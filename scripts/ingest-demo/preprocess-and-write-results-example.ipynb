# %%
# !pip install weaviate-client

# %%
# load creds from .env file (which needs to export OPENAI_API_KEY)
import os
with open('.env', 'r') as env_file:
    for line in env_file:
        key, value = line.strip().split('=')
        os.environ[key] = value

OPENAI_KEY = os.environ.get("OPENAI_API_KEY")

# %%
# fetch our partitioned documents

import os

def get_result_files(folder_path):
    file_list = []
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            if file.endswith('.json'):
                file_path = os.path.join(root, file)
                file_list.append(file_path)
    return file_list

files = get_result_files('results/')
files
# Out:
# ['results/1ZBXs78r2SSgYUZI_ZOwZm_yt7A4n6NL8-FOMC20170201tealbookb20170126.pdf.json',
#  'results/1t2IWeYgHeq8IKUeBLgM9DQ_nwLCXq8Ch-FOMC_LongerRunGoals_201701.pdf.json',
#  "results/1TwH2WPshvwueAHlDiMfe9STLtFgOx-uB-NASA's SpaceX Crew-7 Launches to International Space Station.pdf.json",
#  'results/EmailMessage/02sHn00001EwshAIAR.json',
#  'results/EmailMessage/02sHn00001EwshBIAR.json',
#  'results/EmailMessage/02sHn00001EwshFIAR.json',
#  'results/EmailMessage/02sHn00001EwshtIAB.json',
#  'results/Lead/00QHn000021npFsMAI.json',
#  'results/Lead/00QHn000021npG6MAI.json',
#  'results/Lead/00QHn000021npFzMAI.json',
#  'results/Lead/00QHn000021npFoMAI.json',
#  'results/Lead/00QHn000021npFnMAI.json',
#  'results/Lead/00QHn000021npFrMAI.json',
#  'results/Lead/00QHn000021npG7MAI.json',
#  'results/Lead/00QHn000021npFyMAI.json',
#  'results/Lead/00QHn000021npFpMAI.json',
#  'results/Lead/00QHn000021npG5MAI.json',
#  'results/Lead/00QHn000021npFqMAI.json',
#  'results/Lead/00QHn000021npG4MAI.json',
#  'results/Lead/00QHn000021npFxMAI.json',
#  'results/Lead/00QHn000021npG8MAI.json',
#  'results/Lead/00QHn000021npG1MAI.json',
#  'results/Lead/00QHn000021npFtMAI.json',
#  'results/Lead/00QHn000021npG0MAI.json',
#  'results/Lead/00QHn000021npFuMAI.json',
#  'results/Lead/00QHn000021npG2MAI.json',
#  'results/Lead/00QHn000021npFwMAI.json',
#  'results/Lead/00QHn000021npG3MAI.json',
#  'results/Lead/00QHn000021npFvMAI.json',
#  'results/Campaign/701Hn000001dWeWIAU.json',
#  'results/Campaign/701Hn000001dWeZIAU.json',
#  'results/Campaign/701Hn000001dWeXIAU.json',
#  'results/Campaign/701Hn000001dWeYIAU.json',
#  'results/Case/500Hn00001bslfuIAA.json',
#  'results/Case/500Hn00001bslg0IAA.json',
#  'results/Case/500Hn00001bslg9IAA.json',
#  'results/Case/500Hn00001bslg8IAA.json',
#  'results/Case/500Hn00001bslftIAA.json',
#  'results/Case/500Hn00001bslg1IAA.json',
#  'results/Case/500Hn00001bslfvIAA.json',
#  'results/Case/500Hn00001bslg3IAA.json',
#  'results/Case/500Hn00001bslfwIAA.json',
#  'results/Case/500Hn00001bslg2IAA.json',
#  'results/Case/500Hn00001bslfnIAA.json',
#  'results/Case/500Hn00001bslg7IAA.json',
#  'results/Case/500Hn00001bslgAIAQ.json',
#  'results/Case/500Hn00001bslfrIAA.json',
#  'results/Case/500Hn00001bslg6IAA.json',
#  'results/Case/500Hn00001bslfsIAA.json',
#  'results/Case/500Hn00001bslfzIAA.json',
#  'results/Case/500Hn00001bslfoIAA.json',
#  'results/Case/500Hn00001bslg4IAA.json',
#  'results/Case/500Hn00001bslfqIAA.json',
#  'results/Case/500Hn00001bslgBIAQ.json',
#  'results/Case/500Hn00001bslfmIAA.json',
#  'results/Case/500Hn00001bslfxIAA.json',
#  'results/Case/500Hn00001bslfyIAA.json',
#  'results/Case/500Hn00001bslg5IAA.json',
#  'results/Case/500Hn00001bslfpIAA.json',
#  'results/Account/001Hn00001wCnWKIA0.json',
#  'results/Account/001Hn00001wCnWJIA0.json',
#  'results/Account/001Hn00001wCnWTIA0.json',
#  'results/Account/001Hn00001wCnWIIA0.json',
#  'results/Account/001Hn00001wCnWLIA0.json',
#  'results/Account/001Hn00001wCnWPIA0.json',
#  'results/Account/001Hn00001wCnWQIA0.json',
#  'results/Account/001Hn00001wCnWMIA0.json',
#  'results/Account/001Hn00001wCnWSIA0.json',
#  'results/Account/001Hn00001wCnWOIA0.json',
#  'results/Account/001Hn00001tJVo9IAG.json',
#  'results/Account/001Hn00001wCnWNIA0.json',
#  'results/Account/001Hn00001wCnWRIA0.json',
#  'results/1hXnbJlGkJ86pJsbKVWhjkLRr4X17FK-J-Quantum Computing/1ppcP-AOkTB5ln7CqnwQy9l_Kvtftn4L0-NAE-report-on-quantum-computing.pdf.json',
#  'results/1hXnbJlGkJ86pJsbKVWhjkLRr4X17FK-J-Quantum Computing/1ps9S0TaMC02NahJAfp3NyZo6NVmf7rpM-COVID-19 Accelerates Quantum Computing Adoption, Driving Robust Growth in North America, Europe, and Asia-Pacific.pdf.json',
#  'results/1hXnbJlGkJ86pJsbKVWhjkLRr4X17FK-J-Quantum Computing/1AahuJfN_mmiqqP5E9byMj3cQBZJCanqmZW-YDSaCPC4-Quantum Photonics Market.docx.json',
#  'results/1hXnbJlGkJ86pJsbKVWhjkLRr4X17FK-J-Quantum Computing/180MZG3uAnSsSUbWtTqm2Gmv4GYpe2dnY-honeywell-quantum-encryption.docx.json']

# %%
# set up a weaviate client with document schema

import uuid

import weaviate
from weaviate.embedded import EmbeddedOptions
from weaviate.util import get_valid_uuid

def create_local_weaviate_client():
    return weaviate.Client(
        embedded_options=EmbeddedOptions(
            additional_env_vars={
                "ENABLE_MODULES": "text2vec-openai"
            },
        ),
        additional_headers={
            "X-OpenAI-Api-Key": OPENAI_KEY
        },
    )

def get_schema():
    vectorizer = "text2vec-openai"
    return {
        "classes": [
            {
                "class": "Doc",
                "description": "A generic document class",
                "vectorizer": vectorizer,
                "moduleConfig": {"reranker-cohere": {"model": "rerank-multilingual-v2.0"}},
                "properties": [
                    {
                        "name": "last_modified",
                        "dataType": ["text"],
                        "description": "Last modified date for the document",
                        "moduleConfig": {
                            vectorizer: {
                                "skip": True,  # not including the this property for vectorization
                            },
                        },
                    },
                    {
                        "name": "text",
                        "dataType": ["text"],
                        "description": "Text content for the document",
                    },
                ],
            },
        ],
    }

def upload_schema(my_schema, weaviate):
    weaviate.schema.delete_all()
    weaviate.schema.create(my_schema)

client = create_local_weaviate_client()
my_schema = get_schema()
upload_schema(my_schema, weaviate=client)
# Out:
# embedded weaviate is already listening on port 6666
# Embedded weaviate wasn't listening on port 6666, so starting embedded weaviate again
# Started /Users/ryannikolaidis/.cache/weaviate-embedded: process ID 41926
# {"action":"restapi_management","level":"info","msg":"Shutting down... ","time":"2023-09-18T12:27:47-07:00"}
# {"action":"restapi_management","level":"info","msg":"Stopped serving weaviate at http://127.0.0.1:6666","time":"2023-09-18T12:27:47-07:00"}
# {"action":"startup","default_vectorizer_module":"none","level":"info","msg":"the default vectorizer modules is set to \"none\", as a result all new schema classes without an explicit vectorizer setting, will use this vectorizer","time":"2023-09-18T12:27:47-07:00"}
# {"action":"startup","auto_schema_enabled":true,"level":"info","msg":"auto schema enabled setting is set to \"true\"","time":"2023-09-18T12:27:47-07:00"}
# {"level":"warning","msg":"Multiple vector spaces are present, GraphQL Explore and REST API list objects endpoint module include params has been disabled as a result.","time":"2023-09-18T12:27:47-07:00"}
# {"action":"grpc_startup","level":"info","msg":"grpc server listening at [::]:50051","time":"2023-09-18T12:27:47-07:00"}
# {"action":"hnsw_vector_cache_prefill","count":3000,"index_id":"doc_XKdFc9VwI4Km","level":"info","limit":1000000000000,"msg":"prefilled vector cache","time":"2023-09-18T12:27:47-07:00","took":4118625}
# {"action":"restapi_management","level":"info","msg":"Serving weaviate at http://127.0.0.1:6666","time":"2023-09-18T12:27:47-07:00"}
# {"action":"hnsw_vector_cache_prefill","count":1000,"index_id":"doc_JTJkFmSVKy4b","level":"info","limit":1000000000000,"msg":"prefilled vector cache","time":"2023-09-18T12:27:47-07:00","took":39625}

# %%
from unstructured.chunking.title import chunk_by_title
from unstructured.documents.elements import DataSourceMetadata
from unstructured.partition.json import partition_json

def get_chunks(elements, chunk_under_n_chars=500, chunk_new_after_n_chars=1500):
    for element in elements:
        if not type(element.metadata.data_source) is DataSourceMetadata:
            delattr(element.metadata, "data_source")

        if hasattr(element.metadata, "coordinates"):
            delattr(element.metadata, "coordinates")

    chunks = chunk_by_title(
        elements,
        combine_under_n_chars=chunk_under_n_chars,
        new_after_n_chars=chunk_new_after_n_chars
    )

    for i in range(len(chunks)):
        chunks[i] = {"last_modified": chunks[i].metadata.last_modified, "text": chunks[i].text}

    return chunks


def add_data_to_weaviate(files, weaviate, chunk_under_n_chars=500, chunk_new_after_n_chars=1500):
    for filename in files:
        try:
            elements = partition_json(filename=filename)
            chunks = get_chunks(elements, chunk_under_n_chars, chunk_new_after_n_chars)
        except IndexError as e:
            print(e)
            continue

        print(f"Uploading {len(chunks)} chunks for {str(filename)}.")
        for i, chunk in enumerate(chunks):
            weaviate.batch.add_data_object(
                data_object=chunk,
                class_name="doc",
                uuid=get_valid_uuid(uuid.uuid4()),
            )
        
    weaviate.batch.flush()

add_data_to_weaviate(
    files=files,
    weaviate=client,
    chunk_under_n_chars=75,
    chunk_new_after_n_chars=200
)
# Out:
# Uploading 295 chunks for results/1ZBXs78r2SSgYUZI_ZOwZm_yt7A4n6NL8-FOMC20170201tealbookb20170126.pdf.json.
# Uploading 6 chunks for results/1t2IWeYgHeq8IKUeBLgM9DQ_nwLCXq8Ch-FOMC_LongerRunGoals_201701.pdf.json.
# Uploading 38 chunks for results/1TwH2WPshvwueAHlDiMfe9STLtFgOx-uB-NASA's SpaceX Crew-7 Launches to International Space Station.pdf.json.
# Uploading 7 chunks for results/EmailMessage/02sHn00001EwshAIAR.json.
# Uploading 7 chunks for results/EmailMessage/02sHn00001EwshBIAR.json.
# Uploading 6 chunks for results/EmailMessage/02sHn00001EwshFIAR.json.
# Uploading 7 chunks for results/EmailMessage/02sHn00001EwshtIAB.json.
# Uploading 16 chunks for results/Lead/00QHn000021npFsMAI.json.
# Uploading 16 chunks for results/Lead/00QHn000021npG6MAI.json.
# Uploading 17 chunks for results/Lead/00QHn000021npFzMAI.json.
# Uploading 16 chunks for results/Lead/00QHn000021npFoMAI.json.
# Uploading 16 chunks for results/Lead/00QHn000021npFnMAI.json.
# Uploading 16 chunks for results/Lead/00QHn000021npFrMAI.json.
# Uploading 16 chunks for results/Lead/00QHn000021npG7MAI.json.
# Uploading 16 chunks for results/Lead/00QHn000021npFyMAI.json.
# Uploading 16 chunks for results/Lead/00QHn000021npFpMAI.json.
# Uploading 16 chunks for results/Lead/00QHn000021npG5MAI.json.
# Uploading 16 chunks for results/Lead/00QHn000021npFqMAI.json.
# Uploading 16 chunks for results/Lead/00QHn000021npG4MAI.json.
# Uploading 16 chunks for results/Lead/00QHn000021npFxMAI.json.
# Uploading 16 chunks for results/Lead/00QHn000021npG8MAI.json.
# Uploading 16 chunks for results/Lead/00QHn000021npG1MAI.json.
# Uploading 16 chunks for results/Lead/00QHn000021npFtMAI.json.
# Uploading 16 chunks for results/Lead/00QHn000021npG0MAI.json.
# Uploading 16 chunks for results/Lead/00QHn000021npFuMAI.json.
# Uploading 16 chunks for results/Lead/00QHn000021npG2MAI.json.
# Uploading 16 chunks for results/Lead/00QHn000021npFwMAI.json.
# Uploading 16 chunks for results/Lead/00QHn000021npG3MAI.json.
# Uploading 16 chunks for results/Lead/00QHn000021npFvMAI.json.
# Uploading 10 chunks for results/Campaign/701Hn000001dWeWIAU.json.
# Uploading 10 chunks for results/Campaign/701Hn000001dWeZIAU.json.
# Uploading 10 chunks for results/Campaign/701Hn000001dWeXIAU.json.
# Uploading 10 chunks for results/Campaign/701Hn000001dWeYIAU.json.
# Uploading 10 chunks for results/Case/500Hn00001bslfuIAA.json.
# Uploading 10 chunks for results/Case/500Hn00001bslg0IAA.json.
# Uploading 10 chunks for results/Case/500Hn00001bslg9IAA.json.
# Uploading 10 chunks for results/Case/500Hn00001bslg8IAA.json.
# Uploading 10 chunks for results/Case/500Hn00001bslftIAA.json.
# Uploading 10 chunks for results/Case/500Hn00001bslg1IAA.json.
# Uploading 9 chunks for results/Case/500Hn00001bslfvIAA.json.
# Uploading 10 chunks for results/Case/500Hn00001bslg3IAA.json.
# Uploading 10 chunks for results/Case/500Hn00001bslfwIAA.json.
# Uploading 10 chunks for results/Case/500Hn00001bslg2IAA.json.
# Uploading 9 chunks for results/Case/500Hn00001bslfnIAA.json.
# Uploading 10 chunks for results/Case/500Hn00001bslg7IAA.json.
# Uploading 10 chunks for results/Case/500Hn00001bslgAIAQ.json.
# Uploading 10 chunks for results/Case/500Hn00001bslfrIAA.json.
# Uploading 10 chunks for results/Case/500Hn00001bslg6IAA.json.
# Uploading 10 chunks for results/Case/500Hn00001bslfsIAA.json.
# Uploading 10 chunks for results/Case/500Hn00001bslfzIAA.json.
# Uploading 10 chunks for results/Case/500Hn00001bslfoIAA.json.
# Uploading 10 chunks for results/Case/500Hn00001bslg4IAA.json.
# Uploading 10 chunks for results/Case/500Hn00001bslfqIAA.json.
# Uploading 10 chunks for results/Case/500Hn00001bslgBIAQ.json.
# Uploading 10 chunks for results/Case/500Hn00001bslfmIAA.json.
# Uploading 10 chunks for results/Case/500Hn00001bslfxIAA.json.
# Uploading 9 chunks for results/Case/500Hn00001bslfyIAA.json.
# Uploading 10 chunks for results/Case/500Hn00001bslg5IAA.json.
# Uploading 10 chunks for results/Case/500Hn00001bslfpIAA.json.
# Uploading 22 chunks for results/Account/001Hn00001wCnWKIA0.json.
# Uploading 19 chunks for results/Account/001Hn00001wCnWJIA0.json.
# Uploading 19 chunks for results/Account/001Hn00001wCnWTIA0.json.
# Uploading 23 chunks for results/Account/001Hn00001wCnWIIA0.json.
# Uploading 22 chunks for results/Account/001Hn00001wCnWLIA0.json.
# Uploading 24 chunks for results/Account/001Hn00001wCnWPIA0.json.
# Uploading 22 chunks for results/Account/001Hn00001wCnWQIA0.json.
# Uploading 24 chunks for results/Account/001Hn00001wCnWMIA0.json.
# Uploading 23 chunks for results/Account/001Hn00001wCnWSIA0.json.
# Uploading 24 chunks for results/Account/001Hn00001wCnWOIA0.json.
# Uploading 16 chunks for results/Account/001Hn00001tJVo9IAG.json.
# Uploading 23 chunks for results/Account/001Hn00001wCnWNIA0.json.
# Uploading 22 chunks for results/Account/001Hn00001wCnWRIA0.json.
# Uploading 58 chunks for results/1hXnbJlGkJ86pJsbKVWhjkLRr4X17FK-J-Quantum Computing/1ppcP-AOkTB5ln7CqnwQy9l_Kvtftn4L0-NAE-report-on-quantum-computing.pdf.json.
# Uploading 31 chunks for results/1hXnbJlGkJ86pJsbKVWhjkLRr4X17FK-J-Quantum Computing/1ps9S0TaMC02NahJAfp3NyZo6NVmf7rpM-COVID-19 Accelerates Quantum Computing Adoption, Driving Robust Growth in North America, Europe, and Asia-Pacific.pdf.json.
# Uploading 20 chunks for results/1hXnbJlGkJ86pJsbKVWhjkLRr4X17FK-J-Quantum Computing/1AahuJfN_mmiqqP5E9byMj3cQBZJCanqmZW-YDSaCPC4-Quantum Photonics Market.docx.json.
# Uploading 11 chunks for results/1hXnbJlGkJ86pJsbKVWhjkLRr4X17FK-J-Quantum Computing/180MZG3uAnSsSUbWtTqm2Gmv4GYpe2dnY-honeywell-quantum-encryption.docx.json.

# %%
# query weaviate

def query_weaviate(client, query, limit: int = 10):
    return (
        client.query
        .get('Doc', ['text', 'last_modified'])
        .with_near_text({
            'concepts': [query]
        })
        .with_additional("distance")
        .with_limit(limit)
        .do()
    )

def print_query_and_results(query, results):
    print("\n\n\n-------------------------")
    print(f"QUERY: {query}")
    print("-------------------------")
    for index, result in enumerate(results["data"]["Get"]["Doc"]):
        print(f"\n\n-- RESULT {index}:\n")
        print(result["text"])

queries = [
    "Explore the significance of the Federal Reserve's inflation target and how it is explained.",
    "Find mentions of commercial interest in post-quantum cryptography.",

]

for query in queries:
    results = query_weaviate(client, query, limit=5)
    print_query_and_results(query, results)
# Out:
# -------------------------
# QUERY: Explore the significance of the Federal Reserve's inflation target and how it is explained.
# -------------------------
#
#
# -- RESULT 0:
#
# One notable aspect is the FOMC's inflation target of 2 percent over the longer run. This symmetric inflation goal is communicated clearly to anchor longer-term inflation expectations, which can, in turn, influence price stability and long-term interest rates. Understanding how the Federal Reserve's inflation target aligns with our investment strategies could be crucial in navigating the financial markets.
#
#
# -- RESULT 1:
#
# It's essential that we stay informed about the Federal Reserve's monetary policy and how it might affect our investment strategies. I suggest we schedule a meeting to delve deeper into this topic and explore ways to adjust our investment approach accordingly.
#
#
# -- RESULT 2:
#
# I believe that staying informed about the Federal Reserve's monetary policy strategy and its implications for our investments is essential. Let's schedule a meeting to delve deeper into this topic and explore how we can align our strategies with the evolving economic landscape.
#
#
# -- RESULT 3:
#
# One significant aspect of their strategy is the symmetric inflation goal of 2 percent over the longer run. This goal is communicated to anchor longer-term inflation expectations, which can influence price stability and long-term interest rates. Understanding the potential effects of this inflation target on our investment portfolio is crucial.
#
#
# -- RESULT 4:
#
# The inflation rate over the longer run is primarily determined by monetary policy, and hence the Committee has the ability to specify a longer-run goal for inflation. The Commit- tee reaffirms its judgment that inflation at the rate of 2 percent, as measured by the annual change in the price index for personal con- sumption expenditures, is most consistent over the longer run with the Federal Reserve’s statutory mandate. The Committee would be concerned if inflation were running persistent- ly above or below this objective. Communi- cating this symmetric inflation goal clearly to the public helps keep longer-term inflation expectations firmly anchored, thereby foster- ing price stability and moderate long-term interest rates and enhancing the Committee’s
#
#
#
# -------------------------
# QUERY: Find mentions of commercial interest in post-quantum cryptography.
# -------------------------
#
#
# -- RESULT 0:
#
# There's a growing interest in what's known as "post-quantum cryptography." These are cryptographic algorithms designed to resist attacks from quantum computers. Many experts predict that these algorithms will be standardized in the 2020s. Getting involved in the development and implementation of such algorithms could position us as leaders in the field of quantum-resistant cybersecurity.
#
#
# -- RESULT 1:
#
# I believe that exploring opportunities in the realm of post-quantum cryptography aligns well with our business objectives and could give us a competitive edge in the evolving cybersecurity market. I'd love to discuss this further with you and explore how we can strategically position ourselves in this space.
#
#
# -- RESULT 2:
#
# QUANTUM COMPUTERS AND CRYPTOGRAPHY
#
# Quantum computing will have a major impact on cryptography, which relies upon hard-to-compute problems to protect data. Shor’s algorithm running on a large quantum computer will greatly reduce the required computation (the workfactor) to extract the private key from the asymmetric ciphers used to protect almost all Internet trafﬁc and stored encrypted data. There is strong commercial interest in deploy- ing post-quantum cryptography well before such a quantum computer has been built. Companies and governments cannot afford to have their now-private communications decrypted in the future, even if that future is 30 years away. For this reason, there is a need to begin the transition to post-quantum cryptography as soon as possible, especially since it takes over a decade to make existing Web standards obsolete (see Section 4.4).
#
#
# -- RESULT 3:
#
# In addition to the intellectual and potential societal beneﬁts of quan- tum computing, this ﬁeld has implications for national security. Any entity in possession of a large-scale, practical quantum computer could break today’s asymmetric cryptosystems—a signiﬁcant signals intelli- gence advantage. Awareness of this risk has launched efforts to create and deploy cryptographic-systems that are robust to quantum cryptanalysis, for which there are several candidates currently believed to be quantum safe. However, while deploying post-quantum cryptography in govern- ment and civilian systems may protect subsequent communications, it will not remove the security risk to prequantum encrypted data that has already been intercepted by an adversary, although the magnitude of this risk decreases as the arrival time of a QC capable of deploying Shor’s algorithm increases and the data becomes less relevant. Furthermore, new quantum algorithms or implementations could lead to new quantum cryptanalytic techniques; as with cybersecurity in general, post-quantum resilience will require ongoing security research.
#
#
# -- RESULT 4:
#
# cryptography.
#
# End-user Industry: Various sectors are adopting quantum computing technology,
#
# including banking and nance, IT and telecom, healthcare and pharmaceuticals, space
#
# and defense, energy and power, transportation and logistics, academia, government,
